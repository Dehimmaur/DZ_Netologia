# %%
import pandas as pd

# %%
df = pd.read_csv('file.csv')
df
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0        295665          Macbook Pro Laptop                 1     1700.00
# 1        295666          LG Washing Machine                 1      600.00
# 2        295667        USB-C Charging Cable                 1       11.95
# 3        295668            27in FHD Monitor                 1      149.99
# 4        295669        USB-C Charging Cable                 1       11.95
# ...         ...                         ...               ...         ...
# 24984    319666    Lightning Charging Cable                 1       14.95
# 24985    319667       AA Batteries (4-pack)                 2        3.84
# 24986    319668             Vareebadd Phone                 1      400.00
# 24987    319669            Wired Headphones                 1       11.99
# 24988    319670  Bose SoundSport Headphones                 1       99.99
#
#            Order Date                        Purchase Address
# ...

# %%
df.tail(10)
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 24979    319661      AAA Batteries (4-pack)                 1        2.99
# 24980    319662  Bose SoundSport Headphones                 1       99.99
# 24981    319663               Flatscreen TV                 1      300.00
# 24982    319664             ThinkPad Laptop                 1      999.99
# 24983    319665                      iPhone                 1      700.00
# 24984    319666    Lightning Charging Cable                 1       14.95
# 24985    319667       AA Batteries (4-pack)                 2        3.84
# 24986    319668             Vareebadd Phone                 1      400.00
# 24987    319669            Wired Headphones                 1       11.99
# 24988    319670  Bose SoundSport Headphones                 1       99.99
#
#            Order Date                        Purchase Address
# 24979  12/11/19 21:24         691 West St, Portland, ME 04101
# ...

# %%
df.Product
# Out:
# 0                Macbook Pro Laptop
# 1                LG Washing Machine
# 2              USB-C Charging Cable
# 3                  27in FHD Monitor
# 4              USB-C Charging Cable
#                     ...
# 24984      Lightning Charging Cable
# 24985         AA Batteries (4-pack)
# 24986               Vareebadd Phone
# 24987              Wired Headphones
# 24988    Bose SoundSport Headphones
# Name: Product, Length: 24989, dtype: object

# %%
df['Price Each']
# Out:
# 0        1700.00
# 1         600.00
# 2          11.95
# 3         149.99
# 4          11.95
#           ...
# 24984      14.95
# 24985       3.84
# 24986     400.00
# 24987      11.99
# 24988      99.99
# Name: Price Each, Length: 24989, dtype: float64

# %%
df2 = pd.read_html('https://www.banki.ru/products/hypothec/search/?ysclid=laxytbc3pw965739608')
df2
# Out:
# [                                                  0  \
#  0                                           Продукт
#  1                                  Семейная ипотека
#  2                           Ипотека с господдержкой
#  3                                     Готовое жилье
#  4                                  Льготная ипотека
#  5                                   С господдержкой
#  6                            Господдержка 2020–2022
#  7                                  Льготная ипотека
#  8                                 Госпрограмма 2020
#  9                Новостройка с господдержкой — 2020
#  10                         Госпрограмма 2020 — 2022
#  11                          Льготная ипотека — 2020
#  12  Льготная ипотека на новостройку с господдержкой
#  13                          Льготная ипотека — 2020
#  14                                    Готовое жилье
#  15                          Ипотека с господдержкой
#
# ...

# %%
len(df2)
# Out:
# 1

# %%
df2[0]
# Out:
#                                                   0  \
# 0                                           Продукт
# 1                                  Семейная ипотека
# 2                           Ипотека с господдержкой
# 3                                     Готовое жилье
# 4                                  Льготная ипотека
# 5                                   С господдержкой
# 6                            Господдержка 2020–2022
# 7                                  Льготная ипотека
# 8                                 Госпрограмма 2020
# 9                Новостройка с господдержкой — 2020
# 10                         Госпрограмма 2020 — 2022
# 11                          Льготная ипотека — 2020
# 12  Льготная ипотека на новостройку с господдержкой
# 13                          Льготная ипотека — 2020
# 14                                    Готовое жилье
# 15                          Ипотека с господдержкой
#
#                                  1        2         3          4  \
# ...

# %%
df2 = pd.read_html('https://www.banki.ru/products/hypothec/search/?ysclid=laxytbc3pw965739608')
df2
# Out:
# [                                                  0  \
#  0                                           Продукт
#  1                                  Семейная ипотека
#  2                           Ипотека с господдержкой
#  3                                     Готовое жилье
#  4                                  Льготная ипотека
#  5                                   С господдержкой
#  6                            Господдержка 2020–2022
#  7                                  Льготная ипотека
#  8                                 Госпрограмма 2020
#  9                Новостройка с господдержкой — 2020
#  10                         Госпрограмма 2020 — 2022
#  11                          Льготная ипотека — 2020
#  12  Льготная ипотека на новостройку с господдержкой
#  13                          Льготная ипотека — 2020
#  14                                    Готовое жилье
#  15                          Ипотека с господдержкой
#
# ...

# %%
df2[0]
# Out:
#                                                   0  \
# 0                                           Продукт
# 1                                  Семейная ипотека
# 2                           Ипотека с господдержкой
# 3                                     Готовое жилье
# 4                                  Льготная ипотека
# 5                                   С господдержкой
# 6                            Господдержка 2020–2022
# 7                                  Льготная ипотека
# 8                                 Госпрограмма 2020
# 9                Новостройка с господдержкой — 2020
# 10                         Госпрограмма 2020 — 2022
# 11                          Льготная ипотека — 2020
# 12  Льготная ипотека на новостройку с господдержкой
# 13                          Льготная ипотека — 2020
# 14                                    Готовое жилье
# 15                          Ипотека с господдержкой
#
#                                  1        2         3          4  \
# ...

# %%
import os

# %%
df_oll = pd.DataFrame()
for f in os.listdir(path = '.'):
                    print(f)
# Out:
# .ipynb_checkpoints
# 2 - Чтение и базовые операции.html
# 2 - Чтение и базовые операции.ipynb
# file.csv
# Чтение и БО.ipynb
