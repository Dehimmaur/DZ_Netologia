# %%
import re
counter = ['']
word = 'ростелеком'
w = [char for char in word]
print(w)
count = 0

with open('russian-nouns.txt', 'r', encoding = 'cp1252') as f:
    for line in f:
        line = line.strip().split('\n')
        #counter = counter.append(line[0])
        w2 = [char for char in line[0]]
        w_rost = w
        print(w2)
        l = set(w).intersection(w2)
        if len(l) == len(w2):
            count+=1
            print(line[0])
            
print(count)
# Out:
# ['р', 'о', 'с', 'т', 'е', 'л', 'е', 'к', 'о', 'м']
# ['Р', '°', 'Р', 'ґ']
# ['Р', '°', 'С', 'Ђ']
# ['Р', 'µ', 'С', 'Ђ']
# ['Р', 'ё', 'Р', '»']
# ['Р', 'ѕ', 'Р', 'ј']
# ['С', 'ѓ', 'Р', 'ј']
# ['С', 'ѓ', 'С', 'Ѓ']
# ['С', 'Ћ', 'Р', 'і']
# ['С', 'Ћ', 'С', 'Ђ']
# ['С', 'Ћ', 'С', '‚']
# ['С', 'Џ', 'Р', 'ґ']
# ['С', 'Џ', 'Р', 'є']
# ['С', 'Џ', 'Р', '»']
# ['С', 'Џ', 'С', 'Ѓ']
# ['Р', '°', 'Р', 'ё', 'Р', '»']
# ['Р', '°', 'Р', 'є', 'С', 'Ђ']
# ['Р', '°', 'Р', 'Ѕ', 'С', '‚']
# ['Р', '°', 'С', 'Ђ', 'Р', 'є']
# ['Р', '°', 'С', 'ѓ', 'Р', '»']
# ['Р', '°', 'С', 'ѓ', 'С', '‚']
# ['Р', '±', 'Р', '°', 'Р', '»']
# ['Р', '±', 'Р', 'µ', 'Р', 'і']
# ['Р', '±', 'Р', 'µ', 'Р', '№']
# ['Р', '±', 'Р', 'µ', 'Р', '»']
# ['Р', '±', 'Р', 'ё', 'С', '‚']
# ['Р', '±', 'Р', 'ё', 'С', '‡']
# ['Р', '±', 'Р', 'ѕ', 'Р', 'і']
# ['Р', '±', 'Р', 'ѕ', 'Р', 'є']
# ['Р', '±', 'Р', 'ѕ', 'Р', 'Ѕ']
# ['Р', '±', 'С', 'ѓ', 'Р', '¶']
# ['Р', '±', 'С', 'ѓ', 'Р', '№']
# ['Р', '±', 'С', 'ѓ', 'Р', 'є']
# ['Р', '±', 'С', 'ѓ', 'С', '‚']
# ['Р', '±', 'С', '‹', 'С', '‚']
# ['Р', '±', 'С', 'Ќ', 'С', 'Ђ']
# ['Р', 'І', 'Р', '°', 'Р', '¶']
# ['Р', 'І', 'Р', '°', 'С', 'Ђ']
# ['Р', 'І', 'Р', 'µ', 'Р', 'є']
# ['Р', 'І', 'Р', 'µ', 'С', 'Ѓ']
# ['Р', 'І', 'Р', 'µ', 'С', '…']
# ['Р', 'І', 'Р', 'ё', 'Р', 'і']
# ['Р', 'І', 'Р', 'ё', 'С', 'Ѓ']
# ['Р', 'І', 'Р', 'ѕ', 'Р', '·']
# ['Р', 'І', 'Р', 'ѕ', 'Р', '№']
# ['Р', 'І', 'Р', 'ѕ', 'Р', '»']
# ['Р', 'І', 'Р', 'ѕ', 'С', 'Ђ']
# ['Р', 'І', 'С', 'ѓ', 'Р', '·']
# ['Р', 'І', 'С', 'Џ', 'Р', '·']
# ['Р', 'і', 'Р', 'µ', 'Р', 'Ѕ']
# ['Р', 'і', 'Р', 'ё', 'С', '‚']
# ['Р', 'і', 'Р', 'ѕ', 'Р', 'ґ']
# ['Р', 'і', 'Р', 'ѕ', 'Р', 'Ѕ']
# ['Р', 'і', 'С', 'ѓ', 'Р', '¶']
# ['Р', 'і', 'С', 'ѓ', 'Р', '»']
# ['Р', 'ґ', 'Р', '°', 'С', 'Ђ']
# ['Р', 'ґ', 'Р', 'µ', 'Р', 'ґ']
# ['Р', 'ґ', 'Р', 'µ', 'Р', 'є']
# ['Р', 'ґ', 'Р', 'Ѕ', 'Р', 'ѕ']
# ['Р', 'ґ', 'Р', 'ѕ', 'Р', 'і']
# ['Р', 'ґ', 'Р', 'ѕ', 'Р', '¶']
# ['Р', 'ґ', 'Р', 'ѕ', 'Р', '»']
# ['Р', 'ґ', 'Р', 'ѕ', 'Р', 'ј']
# ['Р', 'ґ', 'Р', 'ѕ', 'С', '‚']
# ['Р', 'ґ', 'С', 'ѓ', 'С', '…']
# ['Р', 'ґ', 'С', 'ѓ', 'С', '€']
# ['Р', 'ґ', 'С', '‹', 'Р', 'ј']
# ['Р', 'µ', 'Р', 'ґ', 'Р', '°']
# ['Р', 'µ', 'Р', '»', 'С', 'Њ']
# ['Р', 'µ', 'С', 'Ђ', 'С', 'Њ']
# ['Р', '¶', 'Р', '°', 'Р', 'ґ']
# ['Р', '¶', 'Р', '°', 'С', 'Ђ']
# ['Р', '¶', 'Р', 'ё', 'Р', 'ј']
# ['Р', '¶', 'Р', 'ѕ', 'С', 'Ђ']
# ['Р', '¶', 'С', 'ѓ', 'Р', 'є']
# ['Р', '·', 'Р', '°', 'Р', 'ґ']
# ['Р', '·', 'Р', '°', 'Р', '»']
# ['Р', '·', 'Р', 'µ', 'Р', 'І']
# ['Р', '·', 'Р', 'µ', 'С', '‚']
# ['Р', '·', 'Р', 'ѕ', 'Р', '±']
# ['Р', '·', 'Р', 'ѕ', 'Р', 'І']
# ['Р', '·', 'С', 'ѓ', 'Р', '±']
# ['Р', '·', 'С', 'ѓ', 'Р', 'ґ']
# ['Р', 'ё', 'Р', 'І', 'Р', '°']
# ['Р', 'ё', 'Р', 'і', 'Р', 'ѕ']
# ['Р', 'ё', 'Р', '·', 'Р', 'ј']
# ['Р', 'ё', 'Р', 'є', 'С', 'Ѓ']
# ['Р', 'ё', 'Р', 'ѕ', 'Р', 'ґ']
# ['Р', 'ё', 'Р', 'ѕ', 'Р', 'Ѕ']
# ['Р', 'ё', 'С', 'Ѓ', 'Р', 'є']
# ['Р', '№', 'Р', 'ѕ', 'Р', 'і']
# ['Р', '№', 'Р', 'ѕ', 'Р', 'ґ']
# ['Р', '№', 'Р', 'ѕ', 'С', '‚']
# ['Р', 'є', 'Р', '°', 'Р', '»']
# ['Р', 'є', 'Р', '°', 'Р', 'Ѕ']
# ['Р', 'є', 'Р', '°', 'С', '‚']
# ['Р', 'є', 'Р', 'µ', 'Р', '±']
# ['Р', 'є', 'Р', 'ё', 'Р', '№']
# ['Р', 'є', 'Р', 'ё', 'Р', '»']
# ['Р', 'є', 'Р', 'ё', 'С', '‚']
# ['Р', 'є', 'Р', 'ѕ', 'Р', 'І']
# ['Р', 'є', 'Р', 'ѕ', 'Р', 'ґ']
# ['Р', 'є', 'Р', 'ѕ', 'Р', '»']
# ['Р', 'є', 'Р', 'ѕ', 'Р', 'ј']
# ['Р', 'є', 'Р', 'ѕ', 'Р', 'Ѕ']
# ['Р', 'є', 'Р', 'ѕ', 'С', '‚']
# ['Р', 'є', 'С', 'ѓ', 'Р', 'ј']
# ['Р', 'є', 'С', 'ѓ', 'Р', 'Ѕ']
# ['Р', 'є', 'С', 'ѓ', 'С', '€']
# ['Р', '»', 'Р', '°', 'Р', 'і']
# ['Р', '»', 'Р', '°', 'Р', '¶']
# ['Р', '»', 'Р', '°', 'Р', '№']
# ['Р', '»', 'Р', '°', 'С', 'Ђ']
# ['Р', '»', 'С', '‘', 'Р', 'ґ']
# ['Р', '»', 'Р', 'µ', 'Р', '№']
# ['Р', '»', 'Р', 'µ', 'Р', 'є']
# ['Р', '»', 'Р', 'µ', 'Р', 'Ѕ']
# ['Р', '»', 'С', '‘', 'Р', 'Ѕ']
# ['Р', '»', 'Р', 'µ', 'С', 'Ѓ']
# ['Р', '»', 'С', '‘', 'С', '‚']
# ['Р', '»', 'Р', 'µ', 'С', '‰']
# ['Р', '»', 'Р', 'µ', 'С', 'Џ']
# ['Р', '»', 'Р', 'ё', 'С', '„']
# ['Р', '»', 'Р', 'ѕ', 'Р', 'І']
# ['Р', '»', 'С', 'ѓ', 'Р', '±']
# ['Р', '»', 'С', 'ѓ', 'Р', 'і']
# ['Р', '»', 'С', 'ѓ', 'С', '‡']
# ['Р', '»', 'С', 'Ћ', 'Р', 'є']
# ['Р', 'ј', 'Р', '°', 'Р', 'і']
# ['Р', 'ј', 'Р', '°', 'Р', '№']
# ['Р', 'ј', 'Р', '°', 'Р', 'є']
# ['Р', 'ј', 'С', '‘', 'Р', 'ґ']
# ['Р', 'ј', 'Р', 'µ', 'Р', '»']
# ['Р', 'ј', 'Р', 'µ', 'С', '‡']
# ['Р', 'ј', 'Р', 'ё', 'Р', 'і']
# ['Р', 'ј', 'Р', 'ё', 'С', '„']
# ['Р', 'ј', 'Р', 'ѕ', 'С', '‚']
# ['Р', 'ј', 'Р', 'ѕ', 'С', '…']
# ['Р', 'ј', 'С', 'ѓ', 'Р', '»']
# ['Р', 'ј', 'С', '‹', 'С', 'Ѓ']
# ['Р', 'ј', 'С', 'Ќ', 'С', 'Ђ']
# ['Р', 'ј', 'С', 'Џ', 'С', '‡']
# ['Р', 'Ѕ', 'Р', 'ё', 'Р', '·']
# ['Р', 'Ѕ', 'Р', 'ѕ', 'Р', '¶']
# ['Р', 'Ѕ', 'Р', 'ѕ', 'Р', 'є']
# ['Р', 'Ѕ', 'Р', 'ѕ', 'С', 'Ѓ']
# ['Р', 'Ѕ', 'С', 'ѓ', 'С', '‚']
# ['Р', 'Ѕ', 'С', 'Ќ', 'Р', 'ї']
# ['Р', 'ѕ', 'Р', '°', 'Р', '·']
# ['Р', 'ѕ', 'Р', 'ґ', 'Р', '°']
# ['Р', 'ѕ', 'Р', 'ї', 'С', '‚']
# ['Р', 'ѕ', 'С', 'Ђ', 'С', 'Ѓ']
# ['Р', 'ѕ', 'С', 'Ђ', 'С', '‚']
# ['Р', 'ѕ', 'С', 'Ѓ', 'Р', '°']
# ['Р', 'ѕ', 'С', 'Ѓ', 'С', '‚']
# ['Р', 'ѕ', 'С', 'Ѓ', 'С', 'Њ']
# ['Р', 'ї', 'Р', '°', 'Р', '¶']
# ['Р', 'ї', 'Р', '°', 'Р', '·']
# ['Р', 'ї', 'Р', '°', 'Р', 'є']
# ['Р', 'ї', 'Р', '°', 'Р', 'Ѕ']
# ['Р', 'ї', 'Р', '°', 'С', '…']
# ['Р', 'ї', 'Р', 'µ', 'Р', 'є']
# ['Р', 'ї', 'Р', 'ё', 'Р', 'є']
# ['Р', 'ї', 'Р', 'ё', 'Р', 'ј']
# ['Р', 'ї', 'Р', 'ё', 'С', 'Ђ']
# ['Р', 'ї', 'Р', 'ѕ', 'С', '‚']
# ['Р', 'ї', 'С', 'ѓ', 'Р', 'ґ']
# ['Р', 'ї', 'С', 'ѓ', 'С', '…']
# ['Р', 'ї', 'С', '‹', 'Р', '»']
# ['Р', 'ї', 'С', 'Ќ', 'С', 'Ђ']
# ['С', 'Ђ', 'Р', '°', 'Р', '±']
# ['С', 'Ђ', 'Р', '°', 'Р', '№']
# ['С', 'Ђ', 'С', '‘', 'Р', 'І']
# ['С', 'Ђ', 'Р', 'µ', 'Р', '№']
# ['С', 'Ђ', 'Р', 'µ', 'С', 'Џ']
# ['С', 'Ђ', 'Р', 'ё', 'С', 'Ѓ']
# ['С', 'Ђ', 'Р', 'ѕ', 'Р', 'І']
# ['С', 'Ђ', 'Р', 'ѕ', 'Р', 'і']
# ['С', 'Ђ', 'Р', 'ѕ', 'Р', '№']
# ['С', 'Ђ', 'Р', 'ѕ', 'Р', '»']
# ['С', 'Ђ', 'Р', 'ѕ', 'Р', 'ј']
# ['С', 'Ђ', 'С', '‹', 'Р', 'є']
# ['С', 'Ђ', 'С', '‹', 'Р', 'ј']
# ['С', 'Ђ', 'С', 'Ћ', 'С', '€']
# ['С', 'Ђ', 'С', 'Џ', 'Р', '¶']
# ['С', 'Ѓ', 'Р', '°', 'Р', 'ґ']
# ['С', 'Ѓ', 'Р', '°', 'Р', '·']
# ['С', 'Ѓ', 'Р', '°', 'Р', 'Ѕ']
# ['С', 'Ѓ', 'Р', 'µ', 'Р', 'І']
# ['С', 'Ѓ', 'Р', 'µ', 'С', '‚']
# ['С', 'Ѓ', 'Р', 'ё', 'Р', 'і']
# ['С', 'Ѓ', 'Р', 'ѕ', 'Р', 'є']
# ['С', 'Ѓ', 'Р', 'ѕ', 'Р', 'ј']
# ['С', 'Ѓ', 'Р', 'ѕ', 'Р', 'Ѕ']
# ['С', 'Ѓ', 'Р', 'ѕ', 'С', 'Ђ']
# ['С', 'Ѓ', 'С', 'ѓ', 'Р', 'ґ']
# ['С', 'Ѓ', 'С', 'ѓ', 'Р', 'є']
# ['С', 'Ѓ', 'С', 'ѓ', 'Р', 'ї']
# ['С', 'Ѓ', 'С', '‹', 'Р', 'Ѕ']
# ['С', 'Ѓ', 'С', '‹', 'С', 'Ђ']
# ['С', 'Ѓ', 'С', 'Ќ', 'С', 'Ђ']
# ['С', '‚', 'Р', '°', 'Р', '»']
# ['С', '‚', 'Р', '°', 'С', '‚']
# ['С', '‚', 'С', '‘', 'С', 'Ѓ']
# ['С', '‚', 'Р', 'ё', 'С', 'Ђ']
# ['С', '‚', 'Р', 'ё', 'С', 'Ѓ']
# ['С', '‚', 'Р', 'ё', 'С', '„']
# ['С', '‚', 'Р', 'ѕ', 'Р', '№']
# ['С', '‚', 'Р', 'ѕ', 'Р', '»']
# ['С', '‚', 'Р', 'ѕ', 'Р', 'ј']
# ['С', '‚', 'С', 'ѓ', 'Р', 'Ѕ']
# ['С', '‚', 'С', 'ѓ', 'С', '„']
# ['С', '‚', 'С', 'ѓ', 'С', 'Џ']
# ['С', '‚', 'С', '‹', 'Р', '»']
# ['С', '‚', 'С', '‹', 'Р', 'Ѕ']
# ['С', '‚', 'С', 'Ќ', 'Р', 'є']
# ['С', '‚', 'С', 'Џ', 'Р', '¶']
# ['С', 'ѓ', 'С', '…', 'Р', '°']
# ['С', 'ѓ', 'С', '…', 'Р', 'ѕ']
# ['С', 'ѓ', 'С', 'Ћ', 'С', '‚']
# ['С', '„', 'Р', '°', 'Р', '»']
# ['С', '„', 'Р', '°', 'С', '‚']
# ['С', '„', 'Р', 'µ', 'Р', 'Ѕ']
# ['С', '„', 'С', '‘', 'Р', 'Ѕ']
# ['С', '„', 'Р', 'µ', 'С', 'Ѓ']
# ['С', '„', 'Р', 'µ', 'С', 'Џ']
# ['С', '„', 'Р', 'ё', 'Р', 'і']
# ['С', '„', 'Р', 'ё', 'С', '€']
# ['С', '„', 'Р', 'ѕ', 'Р', '»']
# ['С', '„', 'Р', 'ѕ', 'С', '‚']
# ['С', '„', 'С', 'ѓ', 'С', '‚']
# ['С', '…', 'Р', '°', 'Р', 'Ѕ']
# ['С', '…', 'Р', 'µ', 'С', 'Ђ']
# ['С', '…', 'Р', 'ё', 'С', '‚']
# ['С', '…', 'Р', 'Ѕ', 'Р', '°']
# ['С', '…', 'Р', 'ѕ', 'Р', 'Ѕ']
# ['С', '…', 'Р', 'ѕ', 'С', 'Ђ']
# ['С', '†', 'Р', 'µ', 'Р', '¶']
# ['С', '†', 'Р', 'µ', 'Р', 'ї']
# ['С', '†', 'С', 'ѓ', 'Р', 'і']
# ['С', '†', 'С', 'ѓ', 'Р', 'є']
# ['С', '‡', 'Р', '°', 'Р', 'ґ']
# ['С', '‡', 'Р', '°', 'Р', '»']
# ['С', '‡', 'Р', '°', 'Р', 'Ѕ']
# ['С', '‡', 'Р', '°', 'С', 'Ѓ']
# ['С', '‡', 'Р', 'µ', 'Р', 'є']
# ['С', '‡', 'Р', 'µ', 'С', '…']
# ['С', '‡', 'Р', 'ё', 'Р', '№']
# ['С', '‡', 'С', 'ѓ', 'Р', '±']
# ['С', '€', 'Р', '°', 'Р', 'і']
# ['С', '€', 'Р', 'µ', 'Р', 'Ѕ']
# ['С', '€', 'Р', 'µ', 'С', '„']
# ['С', '€', 'Р', 'µ', 'С', 'Џ']
# ['С', '€', 'Р', 'ё', 'Р', 'є']
# ['С', '€', 'Р', 'ѕ', 'Р', 'І']
# ['С', '€', 'Р', 'ѕ', 'Р', 'є']
# ['С', '€', 'С', 'ѓ', 'С', '‚']
# ['С', 'Ќ', 'С', 'Ђ', 'Р', 'і']
# ['С', 'Ќ', 'С', '„', 'Р', '°']
# ['С', 'Ќ', 'С', '…', 'Р', 'ѕ']
# ['С', 'Ћ', 'С', 'Ђ', 'Р', '°']
# ['С', 'Џ', 'Р', 'І', 'С', 'Њ']
# ['С', 'Џ', 'Р', '·', 'С', 'Њ']
# ['С', 'Џ', 'Р', 'ј', 'Р', '°']
# ['С', 'Џ', 'Р', 'ј', 'Р', '±']
# ['С', 'Џ', 'С', 'Ђ', 'Р', 'ґ']
# ['С', 'Џ', 'С', '‚', 'С', 'Њ']
# ['Р', '°', 'Р', '±', 'Р', '°', 'Р', '·']
# ['Р', '°', 'Р', 'і', 'Р', '°', 'С', 'Ђ']
# ['Р', '°', 'Р', 'і', 'Р', '°', 'С', '‚']
# ['Р', '°', 'Р', 'і', 'С', 'ѓ', 'Р', '»']
# ['Р', '°', 'Р', 'ґ', 'Р', '°', 'С', '‚']
# ['Р', '°', 'Р', '¶', 'Р', '°', 'Р', 'Ѕ']
# ['Р', '°', 'Р', '·', 'Р', '°', 'Р', 'Ѕ']
# ['Р', '°', 'Р', '·', 'Р', 'ё', 'Р', 'ґ']
# ['Р', '°', 'Р', '·', 'Р', 'ѕ', 'С', '‚']
# ['Р', '°', 'Р', '·', 'С', 'ѓ', 'С', 'Ђ']
# ['Р', '°', 'Р', 'ё', 'С', 'Ѓ', 'С', '‚']
# ['Р', '°', 'Р', '№', 'Р', 'І', 'Р', '°']
# ['Р', '°', 'Р', 'є', 'С', '‹', 'Р', 'Ѕ']
# ['Р', '°', 'Р', 'ј', 'С', 'ѓ', 'С', 'Ђ']
# ['Р', '°', 'Р', 'Ѕ', 'Р', 'ё', 'Р', 'ґ']
# ['Р', '°', 'Р', 'Ѕ', 'Р', 'ѕ', 'Р', 'ґ']
# ['Р', '°', 'С', 'Ђ', 'Р', '°', 'Р', '±']
# ['Р', '°', 'С', 'Ђ', 'Р', '°', 'Р', 'є']
# ['Р', '°', 'С', 'Ђ', 'Р', '°', 'С', '‚']
# ['Р', '°', 'С', 'Ђ', 'Р', '±', 'Р', '°']
# ['Р', '°', 'С', 'Ђ', 'Р', 'ё', 'С', 'Џ']
# ['Р', '°', 'С', 'Ђ', 'Р', 'є', 'Р', '°']
# ['Р', '°', 'С', 'Ђ', 'С', '„', 'Р', '°']
# ['Р', '°', 'С', 'Ђ', 'С', '‡', 'Р', '°']
# ['Р', '°', 'С', 'Ђ', 'С', '‹', 'Р', 'є']
# ['Р', '°', 'С', '‚', 'Р', 'ѕ', 'Р', 'ј']
# ['Р', '°', 'С', 'ѓ', 'С', 'Ђ', 'Р', '°']
# ['Р', '°', 'С', '€', 'С', 'ѓ', 'Р', 'і']
# ['Р', '±', 'Р', '°', 'Р', '·', 'Р', '°']
# ['Р', '±', 'Р', '°', 'Р', 'Ѕ', 'С', '‚']
# ['Р', '±', 'Р', '°', 'Р', 'Ѕ', 'С', 'Џ']
# ['Р', '±', 'Р', '°', 'С', 'Ђ', 'Р', 'ґ']
# ['Р', '±', 'Р', '°', 'С', 'Ђ', 'Р', 'є']
# ['Р', '±', 'Р', '°', 'С', 'Ђ', 'С', 'Ѓ']
# ['Р', '±', 'Р', '°', 'С', 'Ѓ', 'Р', 'є']
# ['Р', '±', 'Р', '°', 'С', 'ѓ', 'Р', '»']
# ['Р', '±', 'Р', 'µ', 'Р', '№', 'С', '‚']
# ['Р', '±', 'Р', 'µ', 'С', '‚', 'Р', '°']
# ['Р', '±', 'Р', 'ё', 'Р', 'є', 'С', 'Ѓ']
# ['Р', '±', 'Р', 'ё', 'Р', '»', 'Р', 'ѕ']
# ['Р', '±', 'Р', 'ё', 'Р', 'ј', 'С', 'Ѓ']
# ['Р', '±', 'Р', 'ё', 'Р', 'Ѕ', 'С', '‚']
# ['Р', '±', 'Р', '»', 'Р', 'µ', 'С', '„']
# ['Р', '±', 'Р', '»', 'Р', 'ё', 'Р', 'є']
# ['Р', '±', 'Р', '»', 'Р', 'ё', 'Р', 'Ѕ']
# ['Р', '±', 'Р', '»', 'Р', 'ё', 'С', '†']
# ['Р', '±', 'Р', '»', 'С', 'ѓ', 'Р', 'ґ']
# ['Р', '±', 'Р', '»', 'С', 'Ћ', 'Р', '·']
# ['Р', '±', 'Р', '»', 'С', 'Ћ', 'Р', 'ј']
# ['Р', '±', 'Р', 'ѕ', 'Р', '±', 'С', 'Ђ']
# ['Р', '±', 'Р', 'ѕ', 'С', '‘', 'Р', 'є']
# ['Р', '±', 'Р', 'ѕ', 'Р', 'µ', 'С', '†']
# ['Р', '±', 'Р', 'ѕ', 'Р', '»', 'С', '‚']
# ['Р', '±', 'Р', 'ѕ', 'Р', '»', 'С', 'Њ']
# ['Р', '±', 'Р', 'ѕ', 'Р', 'Ѕ', 'Р', '°']
# ['Р', '±', 'Р', 'ѕ', 'С', 'Ђ', 'С', '‰']
# ['Р', '±', 'Р', 'ѕ', 'С', 'Ѓ', 'С', 'Ѓ']
# ['Р', '±', 'С', 'Ђ', 'Р', '°', 'С', 'Ѓ']
# ['Р', '±', 'С', 'Ђ', 'Р', '°', 'С', '‚']
# ['Р', '±', 'С', 'Ђ', 'Р', 'µ', 'Р', 'ґ']
# ['Р', '±', 'С', 'Ђ', 'Р', 'ё', 'Р', 'і']
# ['Р', '±', 'С', 'Ђ', 'Р', 'ё', 'Р', '·']
# ['Р', '±', 'С', 'Ђ', 'Р', 'ѕ', 'Р', 'ґ']
# ['Р', '±', 'С', 'Ђ', 'Р', 'ѕ', 'Р', 'ј']
# ['Р', '±', 'С', 'Ђ', 'С', 'ѓ', 'С', 'Ѓ']
# ['Р', '±', 'С', 'ѓ', 'Р', 'µ', 'С', 'Ђ']
# ['Р', '±', 'С', 'ѓ', 'Р', 'є', 'С', 'Ѓ']
# ['Р', '±', 'С', 'ѓ', 'Р', 'Ѕ', 'Р', 'ґ']
# ['Р', '±', 'С', 'ѓ', 'С', 'Ђ', 'Р', '°']
# ['Р', '±', 'С', 'ѓ', 'С', 'Ђ', 'Р', 'і']
# ['Р', '±', 'С', 'ѓ', 'С', 'Ђ', 'С', '‚']
# ['Р', '±', 'С', 'ѓ', 'С', 'Ђ', 'С', 'Џ']
# ['Р', '±', 'С', '‹', 'Р', '»', 'С', 'Њ']
# ['Р', '±', 'С', 'Њ', 'Р', 'µ', 'С', '„']
# ['Р', '±', 'С', 'Ћ', 'С', 'Ѓ', 'С', '‚']
# ['Р', '±', 'С', 'Џ', 'Р', '·', 'С', 'Њ']
# ['Р', 'І', 'Р', '°', 'Р', 'і', 'Р', '°']
# ['Р', 'І', 'Р', '°', 'Р', 'µ', 'С', 'Ђ']
# ['Р', 'І', 'Р', '°', 'Р', '¶', 'Р', '°']
# ['Р', 'І', 'Р', '°', 'Р', '·', 'Р', '°']
# ['Р', 'І', 'Р', '°', 'Р', '№', 'С', 'Џ']
# ['Р', 'І', 'Р', '°', 'С', '‚', 'Р', '°']
# ['Р', 'І', 'Р', '°', 'С', '‚', 'С', '‚']
# ['Р', 'І', 'Р', 'І', 'Р', 'ѕ', 'Р', 'ґ']
# ['Р', 'І', 'Р', 'І', 'Р', 'ѕ', 'Р', '·']
# ['Р', 'І', 'Р', 'і', 'Р', 'ё', 'Р', '±']
# ['Р', 'І', 'Р', 'ґ', 'Р', 'ѕ', 'С', '…']
# ['Р', 'І', 'Р', 'µ', 'Р', 'ґ', 'Р', '°']
# ['Р', 'І', 'Р', 'µ', 'Р', 'µ', 'С', 'Ђ']
# ['Р', 'І', 'Р', 'µ', 'Р', '¶', 'Р', '°']
# ['Р', 'І', 'Р', 'µ', 'Р', 'є', 'Р', 'ѕ']
# ['Р', 'І', 'Р', 'µ', 'Р', 'Ѕ', 'Р', '°']
# ['Р', 'І', 'Р', 'µ', 'Р', 'Ѕ', 'Р', 'ѕ']
# ['Р', 'І', 'Р', 'µ', 'Р', 'ї', 'С', 'Ѓ']
# ['Р', 'І', 'Р', 'µ', 'С', 'Ђ', 'Р', '°']
# ['Р', 'І', 'Р', 'µ', 'С', 'Ђ', 'Р', 'є']
# ['Р', 'І', 'Р', 'µ', 'С', 'Ђ', 'С', '…']
# ['Р', 'І', 'Р', 'µ', 'С', 'Ѓ', 'С', '‚']
# ['Р', 'І', 'Р', 'µ', 'С', '…', 'Р', '°']
# ['Р', 'І', 'Р', 'µ', 'С', '‡', 'Р', 'µ']
# ['Р', 'І', 'Р', 'µ', 'С', '‰', 'С', 'Њ']
# ['Р', 'І', 'Р', '·', 'Р', 'ѕ', 'С', 'Ђ']
# ['Р', 'І', 'Р', 'ё', 'Р', '·', 'Р', '°']
# ['Р', 'І', 'Р', 'ё', 'Р', '·', 'Р', 'і']
# ['Р', 'І', 'Р', 'ё', 'Р', 'є', 'Р', '°']
# ['Р', 'І', 'Р', 'ё', 'Р', 'Ѕ', 'Р', '°']
# ['Р', 'І', 'Р', 'ё', 'Р', 'Ѕ', 'Р', 'ѕ']
# ['Р', 'І', 'Р', '»', 'Р', '°', 'С', 'Ѓ']
# ['Р', 'І', 'Р', 'Ѕ', 'С', 'ѓ', 'Р', 'є']
# ['Р', 'І', 'Р', 'ѕ', 'Р', 'ґ', 'Р', '°']
# ['Р', 'І', 'Р', 'ѕ', 'Р', 'ґ', 'С', 'Њ']
# ['Р', 'І', 'Р', 'ѕ', 'Р', 'ё', 'Р', 'Ѕ']
# ['Р', 'І', 'Р', 'ѕ', 'Р', '№', 'С', '‚']
# ['Р', 'І', 'Р', 'ѕ', 'С', 'Ђ', 'С', 'Ѓ']
# ['Р', 'І', 'Р', 'ѕ', 'С', 'Ѓ', 'Р', 'є']
# ['Р', 'І', 'Р', 'ѕ', 'С', '€', 'С', 'Њ']
# ['Р', 'І', 'С', 'Ђ', 'Р', '°', 'Р', 'і']
# ['Р', 'І', 'С', 'Ђ', 'Р', '°', 'С', '‡']
# ['Р', 'І', 'С', 'Ђ', 'Р', 'µ', 'Р', 'ґ']
# ['Р', 'І', 'С', 'Ђ', 'Р', 'µ', 'Р', '·']
# ['Р', 'І', 'С', 'Ђ', 'С', 'ѓ', 'Р', '±']
# ['Р', 'І', 'С', '‚', 'С', 'ѓ', 'Р', '·']
# ['Р', 'І', 'С', '…', 'Р', 'ѕ', 'Р', 'ґ']
# ['Р', 'І', 'С', '‹', 'Р', 'µ', 'Р', 'ј']
# ['Р', 'І', 'С', '‹', 'Р', 'ј', 'С', 'Џ']
# ['Р', 'І', 'С', '‹', 'Р', 'ї', 'С', 'Њ']
# ['Р', 'І', 'С', '‹', 'С', 'Ѓ', 'С', 'Њ']
# ['Р', 'І', 'С', 'Њ', 'С', 'Ћ', 'Р', 'є']
# ['Р', 'і', 'Р', '°', 'Р', 'і', 'Р', '°']
# ['Р', 'і', 'Р', '°', 'Р', 'µ', 'С', 'Ђ']
# ['Р', 'і', 'Р', '°', 'Р', '»', 'С', 'Ѓ']
# ['Р', 'і', 'Р', '°', 'С', 'Ђ', 'С', '‚']
# ['Р', 'і', 'Р', '°', 'С', 'Ђ', 'С', 'Њ']
# ['Р', 'і', 'Р', '°', 'С', '‚', 'С', 'Њ']
# ['Р', 'і', 'Р', 'µ', 'Р', '№', 'Р', 'ј']
# ['Р', 'і', 'Р', 'µ', 'Р', '»', 'С', 'Њ']
# ['Р', 'і', 'Р', 'µ', 'С', 'Ђ', 'Р', '±']
# ['Р', 'і', 'Р', 'µ', 'С', 'Ђ', 'С', 'Ђ']
# ['Р', 'і', 'Р', 'µ', 'С', 'Ђ', 'С', '†']
# ['Р', 'і', 'Р', 'ё', 'Р', 'ј', 'Р', 'Ѕ']
# ['Р', 'і', 'Р', 'ё', 'Р', 'ї', 'С', 'Ѓ']
# ['Р', 'і', 'Р', 'ё', 'С', 'Ђ', 'С', 'Џ']
# ['Р', 'і', 'Р', 'ё', 'С', '„', 'Р', '°']
# ['Р', 'і', 'Р', '»', 'Р', '°', 'Р', '·']
# ['Р', 'і', 'Р', '»', 'Р', '°', 'С', 'Ѓ']
# ['Р', 'і', 'Р', 'Ѕ', 'Р', 'µ', 'Р', 'І']
# ['Р', 'і', 'Р', 'Ѕ', 'С', '‘', 'С', '‚']
# ['Р', 'і', 'Р', 'Ѕ', 'Р', 'ѕ', 'Р', '№']
# ['Р', 'і', 'Р', 'Ѕ', 'Р', 'ѕ', 'Р', 'ј']
# ['Р', 'і', 'Р', 'ѕ', 'Р', 'Ѕ', 'Р', 'і']
# ['Р', 'і', 'Р', 'ѕ', 'Р', 'Ѕ', 'С', '‚']
# ['Р', 'і', 'Р', 'ѕ', 'С', 'Ђ', 'Р', '°']
# ['Р', 'і', 'Р', 'ѕ', 'С', 'Ђ', 'Р', '±']
# ['Р', 'і', 'Р', 'ѕ', 'С', '„', 'С', 'Ђ']
# ['Р', 'і', 'С', 'Ђ', 'Р', '°', 'Р', '±']
# ['Р', 'і', 'С', 'Ђ', 'Р', '°', 'Р', 'Ѕ']
# ['Р', 'і', 'С', 'Ђ', 'Р', '°', 'С', '„']
# ['Р', 'і', 'С', 'Ђ', 'Р', '°', 'С', '‡']
# ['Р', 'і', 'С', 'Ђ', 'Р', 'µ', 'Р', 'є']
# ['Р', 'і', 'С', 'Ђ', 'Р', 'µ', 'С', '…']
# ['Р', 'і', 'С', 'Ђ', 'Р', 'ё', 'Р', 'ј']
# ['Р', 'і', 'С', 'Ђ', 'Р', 'ѕ', 'Р', 'і']
# ['Р', 'і', 'С', 'Ђ', 'Р', 'ѕ', 'Р', 'ј']
# ['Р', 'і', 'С', 'Ђ', 'Р', 'ѕ', 'С', '€']
# ['Р', 'і', 'С', 'Ђ', 'С', 'ѓ', 'Р', '·']
# ['Р', 'і', 'С', 'Ђ', 'С', 'ѓ', 'Р', 'ј']
# ['Р', 'і', 'С', 'ѓ', 'Р', 'Ѕ', 'Р', 'Ѕ']
# ['Р', 'і', 'С', 'ѓ', 'С', '‰', 'Р', '°']
# ['Р', 'і', 'С', 'Ћ', 'Р', '№', 'С', 'Ѓ']
# ['Р', 'ґ', 'Р', '°', 'Р', '±', 'Р', '°']
# ['Р', 'ґ', 'Р', '°', 'Р', '»', 'С', 'Њ']
# ['Р', 'ґ', 'Р', '°', 'Р', 'ј', 'Р', '°']
# ['Р', 'ґ', 'Р', '°', 'Р', 'Ѕ', 'С', 'Њ']
# ['Р', 'ґ', 'Р', '°', 'С', '‚', 'Р', '°']
# ['Р', 'ґ', 'Р', '°', 'С', 'ѓ', 'С', 'Ђ']
# ['Р', 'ґ', 'Р', 'µ', 'Р', '¶', 'Р', '°']
# ['Р', 'ґ', 'Р', 'µ', 'Р', 'є', 'Р', '°']
# ['Р', 'ґ', 'Р', 'µ', 'Р', '»', 'Р', 'ѕ']
# ['Р', 'ґ', 'Р', 'µ', 'Р', 'Ѕ', 'С', 'Њ']
# ['Р', 'ґ', 'С', '‘', 'С', 'Ђ', 'Р', 'Ѕ']
# ['Р', 'ґ', 'Р', '¶', 'Р', '°', 'Р', '·']
# ['Р', 'ґ', 'Р', '¶', 'Р', 'µ', 'Р', 'ј']
# ['Р', 'ґ', 'Р', '¶', 'Р', 'ё', 'Р', 'Ѕ']
# ['Р', 'ґ', 'Р', '¶', 'Р', 'ё', 'Р', 'ї']
# ['Р', 'ґ', 'Р', '¶', 'Р', 'ѕ', 'Р', 'є']
# ['Р', 'ґ', 'Р', '¶', 'С', 'ѓ', 'С', '‚']
# ['Р', 'ґ', 'Р', '·', 'Р', 'ѕ', 'С', '‚']
# ['Р', 'ґ', 'Р', 'ё', 'Р', 'µ', 'Р', '·']
# ['Р', 'ґ', 'Р', 'ё', 'Р', 'Ѕ', 'Р', '°']
# ['Р', 'ґ', 'Р', 'ё', 'Р', 'ѕ', 'Р', 'ґ']
# ['Р', 'ґ', 'Р', 'ё', 'С', 'Ѓ', 'Р', 'є']
# ['Р', 'ґ', 'Р', 'ё', 'С', '‚', 'С', 'Џ']
# ['Р', 'ґ', 'Р', 'ё', 'С', '‡', 'С', 'Њ']
# ['Р', 'ґ', 'Р', 'ѕ', 'Р', '·', 'Р', '°']
# ['Р', 'ґ', 'Р', 'ѕ', 'Р', '»', 'Р', 'і']
# ['Р', 'ґ', 'Р', 'ѕ', 'Р', 'Ѕ', 'Р', 'і']
# ['Р', 'ґ', 'Р', 'ѕ', 'С', '…', 'Р', '°']
# ['Р', 'ґ', 'Р', 'ѕ', 'С', '‡', 'С', 'Њ']
# ['Р', 'ґ', 'Р', 'ѕ', 'С', 'Џ', 'С', 'Ђ']
# ['Р', 'ґ', 'С', 'Ђ', 'Р', 'µ', 'Р', 'є']
# ['Р', 'ґ', 'С', 'Ђ', 'Р', 'ѕ', 'Р', 'є']
# ['Р', 'ґ', 'С', 'Ђ', 'С', 'ѓ', 'Р', 'і']
# ['Р', 'ґ', 'С', 'Ђ', 'С', 'ѓ', 'Р', '·']
# ['Р', 'ґ', 'С', 'ѓ', 'Р', 'і', 'Р', '°']
# ['Р', 'ґ', 'С', 'ѓ', 'Р', '»', 'Р', 'ѕ']
# ['Р', 'ґ', 'С', 'ѓ', 'С', 'Ѓ', 'С', '‚']
# ['Р', 'ґ', 'С', 'ѓ', 'С', '€', 'Р', '°']
# ['Р', 'ґ', 'С', 'ѓ', 'С', 'Ќ', 'С', '‚']
# ['Р', 'ґ', 'С', '‹', 'Р', '±', 'Р', '°']
# ['Р', 'ґ', 'С', '‹', 'Р', 'Ѕ', 'С', 'Џ']
# ['Р', 'ґ', 'С', '‹', 'С', 'Ђ', 'Р', '°']
# ['Р', 'ґ', 'С', 'Ћ', 'Р', '·', 'Р', '°']
# ['Р', 'ґ', 'С', 'Ћ', 'Р', '№', 'Р', 'ј']
# ['Р', 'ґ', 'С', 'Ћ', 'Р', 'Ѕ', 'Р', '°']
# ['Р', 'ґ', 'С', 'Џ', 'Р', 'ґ', 'С', 'Џ']
# ['Р', 'µ', 'Р', 'ґ', 'Р', 'ѕ', 'Р', 'є']
# ['Р', 'µ', 'Р', '·', 'Р', 'ґ', 'Р', '°']
# ['Р', 'µ', 'Р', '»', 'Р', 'µ', 'Р', '№']
# ['Р', 'µ', 'Р', '»', 'Р', 'µ', 'С', '†']
# ['С', '‘', 'Р', '»', 'Р', 'є', 'Р', '°']
# ['Р', 'µ', 'Р', 'Ѕ', 'Р', 'ѕ', 'С', '‚']
# ['Р', '¶', 'Р', '°', 'Р', '»', 'Р', 'ѕ']
# ['Р', '¶', 'Р', '°', 'Р', 'Ѕ', 'С', 'Ђ']
# ['Р', '¶', 'Р', '°', 'С', 'Ђ', 'Р', '°']
# ['Р', '¶', 'Р', '±', 'Р', '°', 'Р', 'Ѕ']
# ['Р', '¶', 'Р', 'і', 'С', 'ѓ', 'С', '‚']
# ['Р', '¶', 'Р', 'µ', 'Р', '·', 'Р', '»']
# ['Р', '¶', 'Р', 'µ', 'С', 'Ѓ', 'С', '‚']
# ['Р', '¶', 'Р', 'ё', 'Р', 'і', 'Р', '°']
# ['Р', '¶', 'Р', 'ё', 'Р', '¶', 'Р', '°']
# ['Р', '¶', 'Р', 'ј', 'С', '‹', 'С', '…']
# ['Р', '¶', 'Р', 'Ѕ', 'Р', 'µ', 'С', '†']
# ['Р', '¶', 'С', 'Ђ', 'Р', 'µ', 'С', '†']
# ['Р', '¶', 'С', 'ѓ', 'Р', 'ї', 'Р', '°']
# ['Р', '·', 'Р', '°', 'Р', 'і', 'С', 'Ѓ']
# ['Р', '·', 'Р', '°', 'С', '‘', 'Р', 'ј']
# ['Р', '·', 'Р', '°', 'Р', '»', 'Р', '°']
# ['Р', '·', 'Р', '°', 'Р', '»', 'Р', 'ї']
# ['Р', '·', 'Р', '°', 'С', 'Џ', 'С', '†']
# ['Р', '·', 'Р', 'І', 'Р', 'ѕ', 'Р', 'Ѕ']
# ['Р', '·', 'Р', 'І', 'С', 'ѓ', 'Р', 'є']
# ['Р', '·', 'Р', 'ё', 'Р', 'ј', 'Р', '°']
# ['Р', '·', 'Р', '»', 'Р', '°', 'Р', 'є']
# ['Р', '·', 'Р', '»', 'Р', 'ѕ', 'Р', 'µ']
# ['Р', '·', 'Р', 'ј', 'Р', 'µ', 'Р', '№']
# ['Р', '·', 'Р', 'Ѕ', 'Р', '°', 'Р', 'є']
# ['Р', '·', 'Р', 'Ѕ', 'Р', 'ѕ', 'Р', '№']
# ['Р', '·', 'Р', 'ѕ', 'Р', '»', 'Р', '°']
# ['Р', '·', 'Р', 'ѕ', 'Р', 'Ѕ', 'Р', '°']
# ['Р', '·', 'Р', 'ѕ', 'Р', 'Ѕ', 'Р', 'ґ']
# ['Р', '·', 'Р', 'ѕ', 'Р', 'Ѕ', 'С', '‚']
# ['Р', '·', 'С', 'ѓ', 'Р', '°', 'Р', 'І']
# ['Р', '·', 'С', 'ѓ', 'Р', '±', 'С', 'Ђ']
# ['Р', '·', 'С', 'ѓ', 'С', '‘', 'Р', 'є']
# ['Р', '·', 'С', '‹', 'Р', '±', 'С', 'Њ']
# ['Р', '·', 'С', 'Ћ', 'Р', '№', 'Р', 'ґ']
# ['Р', '·', 'С', 'Џ', 'Р', '±', 'С', 'Њ']
# ['Р', '·', 'С', 'Џ', 'С', '‚', 'С', 'Њ']
# ['Р', 'ё', 'Р', '±', 'Р', 'µ', 'С', 'Ђ']
# ['Р', 'ё', 'Р', '±', 'Р', 'ё', 'С', 'Ѓ']
# ['Р', 'ё', 'Р', 'і', 'Р', 'ё', 'Р', '»']
# ['Р', 'ё', 'Р', 'і', 'Р', '»', 'Р', '°']
# ['Р', 'ё', 'Р', 'і', 'С', 'Ђ', 'Р', '°']
# ['Р', 'ё', 'Р', 'ґ', 'Р', 'ё', 'С', '€']
# ['Р', 'ё', 'Р', 'ґ', 'Р', 'ѕ', 'Р', '»']
# ['Р', 'ё', 'Р', 'µ', 'Р', 'Ѕ', 'Р', '°']
# ['Р', 'ё', 'Р', '·', 'С', 'Ћ', 'Р', 'ј']
# ['Р', 'ё', 'Р', '»', 'Р', 'ѕ', 'С', '‚']
# ['Р', 'ё', 'Р', '»', 'С', 'Њ', 'Р', 'ј']
# ['Р', 'ё', 'Р', 'ј', 'Р', '°', 'Р', 'ј']
# ['Р', 'ё', 'Р', 'Ѕ', 'Р', 'µ', 'Р', '№']
# ['Р', 'ё', 'Р', 'Ѕ', 'Р', 'ѕ', 'Р', 'є']
# ['Р', 'ё', 'С', 'Ђ', 'Р', 'і', 'Р', '°']
# ['Р', 'ё', 'С', '‚', 'Р', 'ѕ', 'Р', 'і']
# ['Р', 'ё', 'С', '€', 'Р', '°', 'Р', 'є']
# ['Р', 'ё', 'С', 'Ћ', 'Р', '»', 'С', 'Њ']
# ['Р', 'ё', 'С', 'Ћ', 'Р', 'Ѕ', 'С', 'Њ']
# ['Р', '№', 'Р', 'ѕ', 'Р', 'і', 'Р', '°']
# ['Р', '№', 'Р', 'ѕ', 'С', '‚', 'Р', '°']
# ['Р', 'є', 'Р', '°', 'Р', 'ё', 'Р', 'є']
# ['Р', 'є', 'Р', '°', 'Р', 'ё', 'Р', 'Ѕ']
# ['Р', 'є', 'Р', '°', 'Р', '№', 'С', '„']
# ['Р', 'є', 'Р', '°', 'С', 'Ђ', 'Р', '°']
# ['Р', 'є', 'Р', '°', 'С', 'Ђ', 'Р', 'ї']
# ['Р', 'є', 'Р', '°', 'С', 'Ђ', 'С', '‚']
# ['Р', 'є', 'Р', '°', 'С', 'Ћ', 'С', 'Ђ']
# ['Р', 'є', 'Р', '°', 'С', 'Џ', 'Р', 'є']
# ['Р', 'є', 'Р', 'І', 'Р', '°', 'С', 'Ѓ']
# ['Р', 'є', 'Р', 'µ', 'Р', 'ґ', 'С', 'Ђ']
# ['Р', 'є', 'Р', 'µ', 'Р', 'є', 'С', 'Ѓ']
# ['Р', 'є', 'Р', 'µ', 'С', 'Ђ', 'Р', 'Ѕ']
# ['Р', 'є', 'Р', 'µ', 'С', '‚', 'С', '‡']
# ['Р', 'є', 'Р', 'ё', 'Р', 'є', 'Р', '°']
# ['Р', 'є', 'Р', 'ё', 'Р', 'є', 'С', 'Ѓ']
# ['Р', 'є', 'Р', 'ё', 'Р', '»', 'Р', '°']
# ['Р', 'є', 'Р', 'ё', 'Р', '»', 'С', 'Њ']
# ['Р', 'є', 'Р', 'ё', 'Р', 'ѕ', 'С', '‚']
# ['Р', 'є', 'Р', 'ё', 'Р', 'ї', 'Р', '°']
# ['Р', 'є', 'Р', '»', 'Р', '°', 'Р', 'ґ']
# ['Р', 'є', 'Р', '»', 'Р', '°', 'Р', 'Ѕ']
# ['Р', 'є', 'Р', '»', 'С', '‘', 'Р', 'І']
# ['Р', 'є', 'Р', '»', 'Р', 'µ', 'Р', '№']
# ['Р', 'є', 'Р', '»', 'С', '‘', 'Р', 'Ѕ']
# ['Р', 'є', 'Р', '»', 'С', '‘', 'С', '€']
# ['Р', 'є', 'Р', '»', 'Р', 'µ', 'С', '‰']
# ['Р', 'є', 'Р', '»', 'Р', 'ё', 'Р', 'є']
# ['Р', 'є', 'Р', '»', 'Р', 'ё', 'Р', 'Ѕ']
# ['Р', 'є', 'Р', '»', 'Р', 'ё', 'Р', 'ї']
# ['Р', 'є', 'Р', '»', 'Р', 'ё', 'С', 'Ђ']
# ['Р', 'є', 'Р', '»', 'Р', 'ё', 'С', '‡']
# ['Р', 'є', 'Р', '»', 'Р', 'ѕ', 'Р', 'Ѕ']
# ['Р', 'є', 'Р', '»', 'Р', 'ѕ', 'Р', 'ї']
# ['Р', 'є', 'Р', '»', 'Р', 'ѕ', 'С', '‚']
# ['Р', 'є', 'Р', '»', 'С', '‹', 'Р', 'є']
# ['Р', 'є', 'Р', '»', 'С', 'Ћ', 'Р', 'І']
# ['Р', 'є', 'Р', '»', 'С', 'Ћ', 'Р', '·']
# ['Р', 'є', 'Р', '»', 'С', 'Џ', 'Р', 'ї']
# ['Р', 'є', 'Р', 'Ѕ', 'С', 'ѓ', 'С', '‚']
# ['Р', 'є', 'Р', 'ѕ', 'Р', 'ґ', 'Р', '°']
# ['Р', 'є', 'Р', 'ѕ', 'Р', '¶', 'Р', '°']
# ['Р', 'є', 'Р', 'ѕ', 'Р', 'є', 'Р', 'є']
# ['Р', 'є', 'Р', 'ѕ', 'Р', 'є', 'С', 'Ѓ']
# ['Р', 'є', 'Р', 'ѕ', 'Р', '»', 'Р', '°']
# ['Р', 'є', 'Р', 'ѕ', 'Р', 'ї', 'С', '‚']
# ['Р', 'є', 'Р', 'ѕ', 'Р', 'ї', 'С', 'Њ']
# ['Р', 'є', 'Р', 'ѕ', 'С', 'Ђ', 'Р', '°']
# ['Р', 'є', 'Р', 'ѕ', 'С', 'Ђ', 'Р', 'ґ']
# ['Р', 'є', 'Р', 'ѕ', 'С', 'Ђ', 'Р', '¶']
# ['Р', 'є', 'Р', 'ѕ', 'С', 'Ђ', 'Р', 'ј']
# ['Р', 'є', 'Р', 'ѕ', 'С', 'Ђ', 'С', '‚']
# ['Р', 'є', 'Р', 'ѕ', 'С', 'Ђ', 'С', 'Њ']
# ['Р', 'є', 'С', 'Ђ', 'Р', '°', 'Р', '±']
# ['Р', 'є', 'С', 'Ђ', 'Р', '°', 'Р', '№']
# ['Р', 'є', 'С', 'Ђ', 'Р', '°', 'Р', 'Ѕ']
# ['Р', 'є', 'С', 'Ђ', 'Р', '°', 'Р', 'ї']
# ['Р', 'є', 'С', 'Ђ', 'Р', '°', 'С', '…']
# ['Р', 'є', 'С', 'Ђ', 'Р', 'µ', 'Р', '·']
# ['Р', 'є', 'С', 'Ђ', 'Р', 'µ', 'Р', 'ј']
# ['Р', 'є', 'С', 'Ђ', 'Р', 'µ', 'Р', 'Ѕ']
# ['Р', 'є', 'С', 'Ђ', 'Р', 'µ', 'Р', 'ї']
# ['Р', 'є', 'С', 'Ђ', 'Р', 'ё', 'Р', '·']
# ['Р', 'є', 'С', 'Ђ', 'Р', 'ё', 'Р', 'є']
# ['Р', 'є', 'С', 'Ђ', 'Р', 'ѕ', 'Р', 'І']
# ['Р', 'є', 'С', 'Ђ', 'Р', 'ѕ', 'Р', '№']
# ['Р', 'є', 'С', 'Ђ', 'Р', 'ѕ', 'С', '‚']
# ['Р', 'є', 'С', 'Ђ', 'С', 'ѓ', 'Р', 'і']
# ['Р', 'є', 'С', 'Ђ', 'С', 'Џ', 'Р', '¶']
# ['Р', 'є', 'С', 'ѓ', 'Р', 'і', 'Р', '°']
# ['Р', 'є', 'С', 'ѓ', 'Р', 'ј', 'Р', '°']
# ['Р', 'є', 'С', 'ѓ', 'Р', 'ї', 'Р', '°']
# ['Р', 'є', 'С', 'ѓ', 'С', 'Ђ', 'Р', 'ґ']
# ['Р', 'є', 'С', 'ѓ', 'С', 'Ђ', 'С', 'Ѓ']
# ['Р', 'є', 'С', 'ѓ', 'С', 'Ѓ', 'С', '‚']
# ['Р', 'є', 'С', 'ѓ', 'С', '‡', 'Р', '°']
# ['Р', 'є', 'С', 'ѓ', 'С', '‰', 'Р', '°']
# ['Р', 'є', 'С', 'Њ', 'С', 'Џ', 'С', '‚']
# ['Р', '»', 'Р', '°', 'Р', 'І', 'С', 'Ђ']
# ['Р', '»', 'Р', '°', 'Р', 'Ѕ', 'С', 'Њ']
# ['Р', '»', 'Р', '°', 'Р', 'ї', 'Р', '°']
# ['Р', '»', 'Р', '°', 'С', 'Ђ', 'С', 'Њ']
# ['Р', '»', 'Р', 'і', 'С', 'ѓ', 'Р', 'Ѕ']
# ['Р', '»', 'Р', 'µ', 'Р', 'µ', 'С', 'Ђ']
# ['Р', '»', 'Р', 'µ', 'Р', 'Ѕ', 'С', '‡']
# ['Р', '»', 'С', '‘', 'С', 'Ѓ', 'С', 'Ѓ']
# ['Р', '»', 'Р', 'µ', 'С', '‚', 'Р', 'ѕ']
# ['Р', '»', 'Р', '¶', 'Р', 'µ', 'С', '†']
# ['Р', '»', 'Р', 'ё', 'Р', 'ј', 'Р', '±']
# ['Р', '»', 'Р', 'ё', 'Р', 'Ѕ', 'С', '‚']
# ['Р', '»', 'Р', 'ё', 'С', '‚', 'С', 'Ђ']
# ['Р', '»', 'Р', 'ё', 'С', '„', 'С', '‚']
# ['Р', '»', 'Р', 'ѕ', 'Р', '¶', 'С', 'Њ']
# ['Р', '»', 'Р', 'ѕ', 'Р', '·', 'Р', '°']
# ['Р', '»', 'Р', 'ѕ', 'Р', 'Ѕ', 'Р', 'ѕ']
# ['Р', '»', 'Р', 'ѕ', 'С', 'Ђ', 'Р', 'ґ']
# ['Р', '»', 'Р', 'ѕ', 'С', 'Ѓ', 'Р', 'є']
# ['Р', '»', 'Р', 'ѕ', 'С', 'Ѓ', 'С', 'Њ']
# ['Р', '»', 'С', 'ѓ', 'Р', '¶', 'Р', '°']
# ['Р', '»', 'С', 'ѓ', 'Р', '·', 'Р', '°']
# ['Р', '»', 'С', 'ѓ', 'Р', 'є', 'Р', '°']
# ['Р', '»', 'С', 'ѓ', 'Р', 'Ѕ', 'Р', '°']
# ['Р', '»', 'С', 'ѓ', 'Р', 'Ѕ', 'С', 'Њ']
# ['Р', '»', 'С', 'ѓ', 'Р', 'ї', 'Р', '°']
# ['Р', '»', 'С', '‹', 'Р', '¶', 'Р', '°']
# ['Р', '»', 'С', '‹', 'Р', 'є', 'Р', 'ѕ']
# ['Р', '»', 'С', 'Ћ', 'С', '„', 'Р', '°']
# ['Р', '»', 'С', 'Ћ', 'С', '„', 'С', '‚']
# ['Р', '»', 'С', 'Ћ', 'С', 'Ќ', 'С', 'Ѓ']
# ['Р', '»', 'С', 'Џ', 'Р', '·', 'Р', 'і']
# ['Р', '»', 'С', 'Џ', 'С', 'Ђ', 'Р', 'ґ']
# ['Р', 'ј', 'Р', '°', 'Р', 'І', 'С', 'Ђ']
# ['Р', 'ј', 'Р', '°', 'Р', '·', 'С', 'Њ']
# ['Р', 'ј', 'Р', '°', 'Р', 'ё', 'С', 'Ѓ']
# ['Р', 'ј', 'Р', '°', 'Р', '»', 'Р', '°']
# ['Р', 'ј', 'Р', '°', 'Р', 'ј', 'Р', '°']
# ['Р', 'ј', 'Р', '°', 'Р', 'Ѕ', 'С', '‚']
# ['Р', 'ј', 'Р', '°', 'С', 'Ђ', 'С', 'Ѓ']
# ['Р', 'ј', 'Р', '°', 'С', 'Ђ', 'С', '‚']
# ['Р', 'ј', 'Р', '°', 'С', '‚', 'С', '‡']
# ['Р', 'ј', 'Р', '°', 'С', '†', 'Р', '°']
# ['Р', 'ј', 'Р', '°', 'С', 'Џ', 'Р', 'є']
# ['Р', 'ј', 'Р', 'і', 'Р', '»', 'Р', '°']
# ['Р', 'ј', 'Р', 'µ', 'Р', '¶', 'Р', '°']
# ['Р', 'ј', 'Р', 'µ', 'Р', '»', 'С', 'Њ']
# ['Р', 'ј', 'Р', 'µ', 'Р', 'Ѕ', 'Р', '°']
# ['Р', 'ј', 'Р', 'µ', 'С', 'Ђ', 'Р', '°']
# ['Р', 'ј', 'Р', 'µ', 'С', 'Ђ', 'С', 'Џ']
# ['Р', 'ј', 'Р', 'ё', 'Р', '»', 'С', 'Џ']
# ['Р', 'ј', 'Р', 'ё', 'С', 'Ђ', 'Р', 'ѕ']
# ['Р', 'ј', 'Р', 'ё', 'С', 'Ђ', 'С', 'Ђ']
# ['Р', 'ј', 'Р', 'ё', 'С', 'Ђ', 'С', '‚']
# ['Р', 'ј', 'Р', 'ѕ', 'Р', 'ґ', 'Р', '°']
# ['Р', 'ј', 'Р', 'ѕ', 'Р', '·', 'Р', 'і']
# ['Р', 'ј', 'Р', 'ѕ', 'Р', 'ї', 'С', 'Ѓ']
# ['Р', 'ј', 'Р', 'ѕ', 'С', 'Ђ', 'Р', 'µ']
# ['Р', 'ј', 'Р', 'ѕ', 'С', 'Ђ', 'Р', '¶']
# ['Р', 'ј', 'Р', 'ѕ', 'С', 'Ђ', 'С', 'Ѓ']
# ['Р', 'ј', 'Р', 'ѕ', 'С', 'Ђ', 'С', '„']
# ['Р', 'ј', 'Р', 'ѕ', 'С', 'Ѓ', 'С', '‚']
# ['Р', 'ј', 'Р', 'ѕ', 'С', '‡', 'Р', '°']
# ['Р', 'ј', 'Р', 'ѕ', 'С', '‰', 'С', 'Њ']
# ['Р', 'ј', 'С', 'Ђ', 'Р', '°', 'Р', 'є']
# ['Р', 'ј', 'С', 'ѓ', 'Р', '·', 'Р', '°']
# ['Р', 'ј', 'С', 'ѓ', 'С', 'Ѓ', 'С', 'Ѓ']
# ['Р', 'ј', 'С', 'ѓ', 'С', 'Ѓ', 'С', '‚']
# ['Р', 'ј', 'С', 'ѓ', 'С', '…', 'Р', '°']
# ['Р', 'ј', 'С', '‹', 'Р', '·', 'Р', '°']
# ['Р', 'ј', 'С', '‹', 'Р', '»', 'Р', 'ѕ']
# ['Р', 'ј', 'С', '‹', 'С', '‚', 'Р', 'ѕ']
# ['Р', 'ј', 'С', '‹', 'С', '€', 'С', 'Њ']
# ['Р', 'ј', 'С', 'Ќ', 'С', '‚', 'С', 'Ђ']
# ['Р', 'ј', 'С', 'Ћ', 'Р', 'ѕ', 'Р', 'Ѕ']
# ['Р', 'ј', 'С', 'Џ', 'С', 'Ѓ', 'Р', 'ѕ']
# ['Р', 'ј', 'С', 'Џ', 'С', '‚', 'Р', '°']
# ['Р', 'Ѕ', 'Р', '°', 'С', '‘', 'Р', 'ј']
# ['Р', 'Ѕ', 'Р', '°', 'Р', 'ё', 'Р', '±']
# ['Р', 'Ѕ', 'Р', '°', 'С', 'Ђ', 'Р', 'ґ']
# ['Р', 'Ѕ', 'Р', '°', 'С', 'Ѓ', 'С', '‚']
# ['Р', 'Ѕ', 'Р', '°', 'С', '‚', 'С', 'Ђ']
# ['Р', 'Ѕ', 'Р', 'µ', 'Р', '±', 'Р', 'ѕ']
# ['Р', 'Ѕ', 'С', '‘', 'Р', '±', 'Р', 'ѕ']
# ['Р', 'Ѕ', 'Р', 'µ', 'Р', 'і', 'Р', '°']
# ['Р', 'Ѕ', 'Р', 'µ', 'Р', 'ѕ', 'Р', 'Ѕ']
# ['Р', 'Ѕ', 'Р', 'µ', 'С', 'Ђ', 'Р', 'І']
# ['Р', 'Ѕ', 'Р', 'ё', 'Р', 'І', 'Р', '°']
# ['Р', 'Ѕ', 'Р', 'ё', 'Р', 'І', 'С', '…']
# ['Р', 'Ѕ', 'Р', 'ё', 'Р', 'ј', 'Р', '±']
# ['Р', 'Ѕ', 'Р', 'ё', 'С', '‚', 'С', 'Њ']
# ['Р', 'Ѕ', 'Р', 'ё', 'С', '€', 'Р', '°']
# ['Р', 'Ѕ', 'Р', 'ѕ', 'Р', 'І', 'С', 'Њ']
# ['Р', 'Ѕ', 'Р', 'ѕ', 'Р', 'і', 'Р', '°']
# ['Р', 'Ѕ', 'Р', 'ѕ', 'Р', '»', 'С', 'Њ']
# ['Р', 'Ѕ', 'Р', 'ѕ', 'Р', 'ј', 'Р', '°']
# ['Р', 'Ѕ', 'Р', 'ѕ', 'Р', 'Ѕ', 'Р', '°']
# ['Р', 'Ѕ', 'Р', 'ѕ', 'С', 'Ђ', 'Р', '°']
# ['Р', 'Ѕ', 'Р', 'ѕ', 'С', 'Ђ', 'Р', 'ґ']
# ['Р', 'Ѕ', 'Р', 'ѕ', 'С', '‡', 'С', 'Њ']
# ['Р', 'Ѕ', 'Р', 'ѕ', 'С', '€', 'Р', '°']
# ['Р', 'Ѕ', 'С', 'Ђ', 'Р', '°', 'Р', 'І']
# ['Р', 'Ѕ', 'С', 'ѓ', 'Р', 'і', 'Р', '°']
# ['Р', 'Ѕ', 'С', 'ѓ', 'Р', '»', 'С', 'Њ']
# ['Р', 'Ѕ', 'С', 'Џ', 'Р', 'Ѕ', 'С', 'Џ']
# ['Р', 'ѕ', 'Р', '±', 'Р', 'µ', 'Р', 'ґ']
# ['Р', 'ѕ', 'Р', '±', 'Р', 'µ', 'С', '‚']
# ['Р', 'ѕ', 'Р', '±', 'Р', 'ѕ', 'Р', 'ґ']
# ['Р', 'ѕ', 'Р', '±', 'Р', 'ѕ', 'Р', '·']
# ['Р', 'ѕ', 'Р', '±', 'Р', 'ѕ', 'Р', '№']
# ['Р', 'ѕ', 'Р', '±', 'Р', 'ѕ', 'Р', '»']
# ['Р', 'ѕ', 'Р', 'І', 'Р', '°', 'Р', '»']
# ['Р', 'ѕ', 'Р', 'І', 'С', '‘', 'С', 'Ѓ']
# ['Р', 'ѕ', 'Р', 'І', 'Р', 'ё', 'Р', 'Ѕ']
# ['Р', 'ѕ', 'Р', 'І', 'Р', 'ѕ', 'Р', 'ґ']
# ['Р', 'ѕ', 'Р', 'І', 'Р', 'ѕ', 'С', '‰']
# ['Р', 'ѕ', 'Р', 'ґ', 'С', 'ѓ', 'Р', '»']
# ['Р', 'ѕ', 'Р', '¶', 'Р', 'ѕ', 'Р', 'і']
# ['Р', 'ѕ', 'Р', '·', 'Р', 'ѕ', 'Р', 'Ѕ']
# ['Р', 'ѕ', 'Р', 'є', 'Р', 'Ѕ', 'Р', 'ѕ']
# ['Р', 'ѕ', 'Р', 'є', 'Р', 'ѕ', 'Р', 'ї']
# ['Р', 'ѕ', 'Р', 'є', 'Р', 'ѕ', 'С', '‚']
# ['Р', 'ѕ', 'Р', 'ј', 'Р', '°', 'С', 'Ђ']
# ['Р', 'ѕ', 'Р', 'ј', 'Р', 'µ', 'Р', 'і']
# ['Р', 'ѕ', 'Р', 'ј', 'С', '‘', 'С', '‚']
# ['Р', 'ѕ', 'Р', 'ј', 'С', 'ѓ', 'С', '‚']
# ['Р', 'ѕ', 'Р', 'Ѕ', 'С', '‘', 'С', 'Ђ']
# ['Р', 'ѕ', 'Р', 'ї', 'Р', '°', 'Р', 'є']
# ['Р', 'ѕ', 'Р', 'ї', 'Р', '°', 'Р', '»']
# ['Р', 'ѕ', 'Р', 'ї', 'Р', 'ё', 'Р', '№']
# ['Р', 'ѕ', 'Р', 'ї', 'Р', 'ѕ', 'Р', '№']
# ['Р', 'ѕ', 'Р', 'ї', 'С', 'ѓ', 'С', 'Ѓ']
# ['Р', 'ѕ', 'Р', 'ї', 'С', '‹', 'С', '‚']
# ['Р', 'ѕ', 'С', 'Ђ', 'Р', 'ґ', 'Р', '°']
# ['Р', 'ѕ', 'С', 'Ђ', 'Р', 'ѕ', 'Р', 'є']
# ['Р', 'ѕ', 'С', 'Ђ', 'Р', 'ѕ', 'С', '‡']
# ['Р', 'ѕ', 'С', 'Ѓ', 'Р', 'µ', 'Р', 'є']
# ['Р', 'ѕ', 'С', 'Ѓ', 'С', '‘', 'Р', '»']
# ['Р', 'ѕ', 'С', 'Ѓ', 'Р', 'ѕ', 'С', 'Ѓ']
# ['Р', 'ѕ', 'С', 'Ѓ', 'Р', 'ѕ', 'С', '‚']
# ['Р', 'ѕ', 'С', 'Ѓ', 'Р', 'ї', 'Р', '°']
# ['Р', 'ѕ', 'С', 'Ѓ', 'С', '‚', 'С', 'Њ']
# ['Р', 'ѕ', 'С', '‚', 'С', '‘', 'Р', 'є']
# ['Р', 'ѕ', 'С', '‚', 'С', '‘', 'Р', '»']
# ['Р', 'ѕ', 'С', '‚', 'Р', 'µ', 'С', '†']
# ['Р', 'ѕ', 'С', '„', 'Р', 'ё', 'С', '‚']
# ['Р', 'ѕ', 'С', '…', 'С', 'Ђ', 'Р', '°']
# ['Р', 'ѕ', 'С', '‡', 'Р', '°', 'Р', 'і']
# ['Р', 'ѕ', 'С', '‡', 'С', '‘', 'С', 'Ѓ']
# ['Р', 'ѕ', 'С', '€', 'Р', 'І', 'Р', '°']
# ['Р', 'ї', 'Р', '°', 'Р', 'І', 'Р', '°']
# ['Р', 'ї', 'Р', '°', 'С', '‘', 'Р', 'є']
# ['Р', 'ї', 'Р', '°', 'Р', 'є', 'С', '‚']
# ['Р', 'ї', 'Р', '°', 'С', 'Ђ', 'С', 'Ѓ']
# ['Р', 'ї', 'Р', '°', 'С', 'Ѓ', 'Р', 'є']
# ['Р', 'ї', 'Р', '°', 'С', 'Ѓ', 'С', 'Ѓ']
# ['Р', 'ї', 'Р', '°', 'С', '€', 'Р', '°']
# ['Р', 'ї', 'Р', '°', 'С', 'Ћ', 'С', 'Ѓ']
# ['Р', 'ї', 'Р', '°', 'С', 'Џ', 'С', '†']
# ['Р', 'ї', 'Р', 'µ', 'Р', 'І', 'Р', 'і']
# ['Р', 'ї', 'Р', 'µ', 'Р', '№', 'С', 'Ѓ']
# ['Р', 'ї', 'Р', 'µ', 'Р', 'Ѕ', 'Р', '°']
# ['Р', 'ї', 'Р', 'µ', 'Р', 'Ѕ', 'С', 'Ѓ']
# ['Р', 'ї', 'Р', 'µ', 'С', 'Ђ', 'Р', 'ѕ']
# ['Р', 'ї', 'Р', 'µ', 'С', 'Ђ', 'С', 'Ѓ']
# ['Р', 'ї', 'Р', 'µ', 'С', 'Ђ', 'С', '€']
# ['Р', 'ї', 'Р', 'µ', 'С', 'Ѓ', 'С', '‚']
# ['Р', 'ї', 'Р', 'ё', 'Р', 'І', 'Р', 'ѕ']
# ['Р', 'ї', 'Р', 'ё', 'Р', 'є', 'Р', '°']
# ['Р', 'ї', 'Р', 'ё', 'Р', 'ѕ', 'Р', 'Ѕ']
# ['Р', 'ї', 'Р', 'ё', 'С', 'Ђ', 'С', 'Ѓ']
# ['Р', 'ї', 'Р', 'ё', 'С', 'Ѓ', 'Р', 'є']
# ['Р', 'ї', 'Р', 'ё', 'С', '‰', 'Р', '°']
# ['Р', 'ї', 'Р', '»', 'Р', '°', 'Р', '·']
# ['Р', 'ї', 'Р', '»', 'Р', '°', 'Р', 'Ѕ']
# ['Р', 'ї', 'Р', '»', 'Р', '°', 'С', '†']
# ['Р', 'ї', 'Р', '»', 'Р', '°', 'С', '‡']
# ['Р', 'ї', 'Р', '»', 'Р', '°', 'С', '‰']
# ['Р', 'ї', 'Р', '»', 'Р', 'µ', 'Р', 'ґ']
# ['Р', 'ї', 'Р', '»', 'Р', 'µ', 'Р', 'Ѕ']
# ['Р', 'ї', 'Р', '»', 'Р', 'ё', 'С', 'Ѓ']
# ['Р', 'ї', 'Р', '»', 'Р', 'ѕ', 'Р', 'І']
# ['Р', 'ї', 'Р', '»', 'Р', 'ѕ', 'С', '‚']
# ['Р', 'ї', 'Р', '»', 'С', 'ѓ', 'Р', 'і']
# ['Р', 'ї', 'Р', '»', 'С', 'Ћ', 'С', 'Ђ']
# ['Р', 'ї', 'Р', '»', 'С', 'Ћ', 'С', '€']
# ['Р', 'ї', 'Р', '»', 'С', 'Ћ', 'С', '‰']
# ['Р', 'ї', 'Р', '»', 'С', 'Џ', 'Р', '¶']
# ['Р', 'ї', 'Р', 'ѕ', 'Р', '·', 'Р', '°']
# ['Р', 'ї', 'Р', 'ѕ', 'Р', '»', 'Р', '°']
# ['Р', 'ї', 'Р', 'ѕ', 'Р', '»', 'Р', 'є']
# ['Р', 'ї', 'Р', 'ѕ', 'С', 'Ќ', 'С', '‚']
# ['Р', 'ї', 'С', 'Ђ', 'Р', '°', 'С', '…']
# ['Р', 'ї', 'С', 'Ђ', 'Р', '°', 'С', '‰']
# ['Р', 'ї', 'С', 'Ђ', 'С', 'ѓ', 'Р', 'ґ']
# ['Р', 'ї', 'С', 'Ђ', 'С', 'ѓ', 'С', 'Ѓ']
# ['Р', 'ї', 'С', 'Ђ', 'С', 'ѓ', 'С', '‚']
# ['Р', 'ї', 'С', 'Ђ', 'С', '‹', 'С', '‰']
# ['Р', 'ї', 'С', 'ѓ', 'Р', '°', 'Р', '·']
# ['Р', 'ї', 'С', 'ѓ', 'Р', '»', 'Р', '°']
# ['Р', 'ї', 'С', 'ѓ', 'Р', '»', 'Р', 'ѕ']
# ['Р', 'ї', 'С', 'ѓ', 'Р', 'ј', 'Р', '°']
# ['Р', 'ї', 'С', 'ѓ', 'Р', 'Ѕ', 'С', '€']
# ['Р', 'ї', 'С', 'ѓ', 'Р', 'ї', 'С', 'Ѓ']
# ['Р', 'ї', 'С', 'ѓ', 'С', 'Ѓ', 'Р', 'є']
# ['Р', 'ї', 'С', 'ѓ', 'С', '‚', 'С', '‡']
# ['Р', 'ї', 'С', 'ѓ', 'С', '‚', 'С', 'Њ']
# ['Р', 'ї', 'С', 'ѓ', 'С', '‰', 'Р', '°']
# ['Р', 'ї', 'С', '€', 'Р', '°', 'С', '‚']
# ['Р', 'ї', 'С', 'Џ', 'Р', 'ґ', 'С', 'Њ']
# ['Р', 'ї', 'С', 'Џ', 'Р', '»', 'Р', '°']
# ['Р', 'ї', 'С', 'Џ', 'С', '‚', 'Р', '°']
# ['С', 'Ђ', 'Р', '°', 'Р', '±', 'Р', '°']
# ['С', 'Ђ', 'Р', '°', 'Р', 'є', 'Р', '°']
# ['С', 'Ђ', 'Р', '°', 'Р', 'ј', 'Р', '°']
# ['С', 'Ђ', 'Р', '°', 'Р', 'ј', 'С', 'Ѓ']
# ['С', 'Ђ', 'Р', '°', 'Р', 'Ѕ', 'Р', '°']
# ['С', 'Ђ', 'Р', '°', 'Р', 'Ѕ', 'Р', 'і']
# ['С', 'Ђ', 'Р', '°', 'Р', 'Ѕ', 'С', '‚']
# ['С', 'Ђ', 'Р', '°', 'Р', 'ї', 'Р', '°']
# ['С', 'Ђ', 'Р', '°', 'Р', 'ї', 'С', 'Ѓ']
# ['С', 'Ђ', 'Р', '°', 'С', '‚', 'С', 'Њ']
# ['С', 'Ђ', 'Р', '°', 'С', 'ѓ', 'С', 'Ѓ']
# ['С', 'Ђ', 'Р', '°', 'С', 'ѓ', 'С', '‚']
# ['С', 'Ђ', 'Р', 'µ', 'Р', '·', 'С', 'Њ']
# ['С', 'Ђ', 'Р', 'µ', 'Р', '№', 'С', 'Ѓ']
# ['С', 'Ђ', 'Р', 'µ', 'Р', 'є', 'Р', '°']
# ['С', 'Ђ', 'Р', 'µ', 'Р', 'ї', 'Р', '°']
# ['С', 'Ђ', 'Р', 'µ', 'Р', 'ї', 'С', 'Ѓ']
# ['С', 'Ђ', 'Р', 'ё', 'Р', '°', 'Р', '»']
# ['С', 'Ђ', 'Р', 'ё', 'Р', 'і', 'Р', '°']
# ['С', 'Ђ', 'Р', 'ё', 'Р', 'Ѕ', 'Р', 'і']
# ['С', 'Ђ', 'Р', 'ё', 'Р', 'Ѕ', 'Р', 'є']
# ['С', 'Ђ', 'Р', 'ё', 'С', 'Ѓ', 'Р', 'є']
# ['С', 'Ђ', 'Р', 'ё', 'С', '‚', 'Р', 'ј']
# ['С', 'Ђ', 'Р', 'ѕ', 'Р', '¶', 'С', 'Њ']
# ['С', 'Ђ', 'Р', 'ѕ', 'Р', '»', 'Р', '»']
# ['С', 'Ђ', 'Р', 'ѕ', 'С', 'Ѓ', 'Р', '°']
# ['С', 'Ђ', 'Р', 'ѕ', 'С', 'Ѓ', 'С', '‚']
# ['С', 'Ђ', 'Р', 'ѕ', 'С', '‚', 'Р', '°']
# ['С', 'Ђ', 'Р', 'ѕ', 'С', '‰', 'Р', '°']
# ['С', 'Ђ', 'С', 'ѓ', 'Р', 'є', 'Р', '°']
# ['С', 'Ђ', 'С', 'ѓ', 'Р', '»', 'С', 'Њ']
# ['С', 'Ђ', 'С', 'ѓ', 'Р', 'ј', 'Р', '±']
# ['С', 'Ђ', 'С', 'ѓ', 'С', 'Ѓ', 'С', '‚']
# ['С', 'Ђ', 'С', 'ѓ', 'С', '‚', 'Р', '°']
# ['С', 'Ђ', 'С', '‹', 'Р', '»', 'Р', 'ѕ']
# ['С', 'Ђ', 'С', 'Ћ', 'С', '…', 'Р', '°']
# ['С', 'Ђ', 'С', 'Џ', 'Р', '±', 'С', 'Њ']
# ['С', 'Ђ', 'С', 'Џ', 'С', 'Ѓ', 'Р', '°']
# ['С', 'Ѓ', 'Р', '°', 'Р', '°', 'Р', '·']
# ['С', 'Ѓ', 'Р', '°', 'Р', '°', 'Р', 'ј']
# ['С', 'Ѓ', 'Р', '°', 'Р', '±', 'Р', '°']
# ['С', 'Ѓ', 'Р', '°', 'Р', 'і', 'Р', '°']
# ['С', 'Ѓ', 'Р', '°', 'С', '‘', 'Р', 'є']
# ['С', 'Ѓ', 'Р', '°', 'Р', '¶', 'Р', '°']
# ['С', 'Ѓ', 'Р', '°', 'Р', 'ё', 'Р', '±']
# ['С', 'Ѓ', 'Р', '°', 'Р', 'є', 'С', 'Ѓ']
# ['С', 'Ѓ', 'Р', '°', 'Р', 'ї', 'Р', '°']
# ['С', 'Ѓ', 'Р', '°', 'С', 'Ђ', 'Р', 'ґ']
# ['С', 'Ѓ', 'Р', '±', 'С', '‹', 'С', '‚']
# ['С', 'Ѓ', 'Р', 'І', 'Р', '°', 'Р', 'Ѕ']
# ['С', 'Ѓ', 'Р', 'І', 'Р', '°', 'С', 'Џ']
# ['С', 'Ѓ', 'Р', 'І', 'Р', 'µ', 'С', 'Ѓ']
# ['С', 'Ѓ', 'Р', 'І', 'Р', 'ё', 'С', '‰']
# ['С', 'Ѓ', 'Р', 'І', 'Р', 'ѕ', 'Р', 'ґ']
# ['С', 'Ѓ', 'Р', 'І', 'Р', 'ѕ', 'С', '‘']
# ['С', 'Ѓ', 'Р', 'І', 'Р', 'ѕ', 'Р', '·']
# ['С', 'Ѓ', 'Р', 'і', 'Р', 'ё', 'Р', '±']
# ['С', 'Ѓ', 'Р', 'і', 'Р', 'ѕ', 'Р', 'Ѕ']
# ['С', 'Ѓ', 'Р', 'µ', 'Р', 'І', 'С', 'Ђ']
# ['С', 'Ѓ', 'Р', 'µ', 'Р', 'ё', 'Р', 'ґ']
# ['С', 'Ѓ', 'Р', 'µ', 'Р', '№', 'Р', 'ј']
# ['С', 'Ѓ', 'Р', 'µ', 'Р', '№', 'С', '„']
# ['С', 'Ѓ', 'Р', 'µ', 'Р', 'є', 'С', 'Ѓ']
# ['С', 'Ѓ', 'Р', 'µ', 'Р', '»', 'Р', 'ѕ']
# ['С', 'Ѓ', 'Р', 'µ', 'Р', '»', 'С', 'Њ']
# ['С', 'Ѓ', 'Р', 'µ', 'Р', 'ј', 'Р', '°']
# ['С', 'Ѓ', 'Р', 'µ', 'Р', 'ј', 'С', 'Џ']
# ['С', 'Ѓ', 'Р', 'µ', 'Р', 'Ѕ', 'Р', 'ѕ']
# ['С', 'Ѓ', 'Р', 'µ', 'С', 'Ђ', 'Р', '°']
# ['С', 'Ѓ', 'Р', 'µ', 'С', 'Ђ', 'Р', '±']
# ['С', 'Ѓ', 'Р', 'µ', 'С', 'Ђ', 'Р', 'І']
# ['С', 'Ѓ', 'Р', 'µ', 'С', 'Ђ', 'Р', 'ї']
# ['С', 'Ѓ', 'Р', 'µ', 'С', '‚', 'С', 'Њ']
# ['С', 'Ѓ', 'Р', '¶', 'Р', 'ё', 'Р', 'ј']
# ['С', 'Ѓ', 'Р', 'ё', 'Р', 'ґ', 'С', 'Ђ']
# ['С', 'Ѓ', 'Р', 'ё', 'Р', 'є', 'Р', '»']
# ['С', 'Ѓ', 'Р', 'ё', 'Р', '»', 'С', 'Њ']
# ['С', 'Ѓ', 'Р', 'ё', 'С', '‚', 'Р', 'ѕ']
# ['С', 'Ѓ', 'Р', 'є', 'Р', '°', 'Р', '·']
# ['С', 'Ѓ', 'Р', 'є', 'Р', 'ё', 'Р', 'ї']
# ['С', 'Ѓ', 'Р', 'є', 'Р', 'ё', 'С', '‚']
# ['С', 'Ѓ', 'Р', 'є', 'Р', 'ѕ', 'Р', '»']
# ['С', 'Ѓ', 'Р', 'є', 'Р', 'ѕ', 'С', '‚']
# ['С', 'Ѓ', 'Р', '»', 'Р', 'µ', 'Р', 'ґ']
# ['С', 'Ѓ', 'Р', '»', 'Р', 'ё', 'Р', 'І']
# ['С', 'Ѓ', 'Р', '»', 'Р', 'ё', 'Р', 'ї']
# ['С', 'Ѓ', 'Р', '»', 'Р', 'ѕ', 'Р', '№']
# ['С', 'Ѓ', 'Р', '»', 'Р', 'ѕ', 'Р', 'ј']
# ['С', 'Ѓ', 'Р', '»', 'С', 'ѓ', 'С', '…']
# ['С', 'Ѓ', 'Р', '»', 'С', 'Џ', 'Р', '±']
# ['С', 'Ѓ', 'Р', 'ј', 'Р', 'ѕ', 'Р', 'і']
# ['С', 'Ѓ', 'Р', 'Ѕ', 'Р', 'µ', 'Р', 'і']
# ['С', 'Ѓ', 'Р', 'Ѕ', 'Р', 'ѕ', 'Р', '±']
# ['С', 'Ѓ', 'Р', 'Ѕ', 'Р', 'ѕ', 'Р', 'ї']
# ['С', 'Ѓ', 'Р', 'ѕ', 'Р', 'І', 'Р', '°']
# ['С', 'Ѓ', 'Р', 'ѕ', 'Р', 'ґ', 'Р', '°']
# ['С', 'Ѓ', 'Р', 'ѕ', 'Р', 'ј', 'Р', '°']
# ['С', 'Ѓ', 'Р', 'ѕ', 'С', 'Ђ', 'С', '‚']
# ['С', 'Ѓ', 'Р', 'ѕ', 'С', 'ѓ', 'С', 'Ѓ']
# ['С', 'Ѓ', 'Р', 'ѕ', 'С', '„', 'Р', '°']
# ['С', 'Ѓ', 'Р', 'ї', 'Р', '°', 'Р', 'ґ']
# ['С', 'Ѓ', 'Р', 'ї', 'Р', 'ё', 'Р', '»']
# ['С', 'Ѓ', 'Р', 'ї', 'Р', 'ё', 'С', '‡']
# ['С', 'Ѓ', 'Р', 'ї', 'Р', 'ѕ', 'С', 'Ђ']
# ['С', 'Ѓ', 'С', 'Ђ', 'Р', 'µ', 'Р', '·']
# ['С', 'Ѓ', 'С', 'Ђ', 'Р', 'ѕ', 'Р', 'є']
# ['С', 'Ѓ', 'С', 'Ђ', 'С', 'ѓ', 'Р', '±']
# ['С', 'Ѓ', 'С', 'Ђ', 'С', '‹', 'Р', 'І']
# ['С', 'Ѓ', 'С', '‚', 'Р', '°', 'Р', '¶']
# ['С', 'Ѓ', 'С', '‚', 'Р', 'µ', 'Р', 'є']
# ['С', 'Ѓ', 'С', '‚', 'Р', 'µ', 'Р', 'Ѕ']
# ['С', 'Ѓ', 'С', '‚', 'Р', 'µ', 'Р', 'ї']
# ['С', 'Ѓ', 'С', '‚', 'Р', 'ѕ', 'Р', 'і']
# ['С', 'Ѓ', 'С', '‚', 'Р', 'ѕ', 'Р', 'є']
# ['С', 'Ѓ', 'С', '‚', 'Р', 'ѕ', 'Р', 'Ѕ']
# ['С', 'Ѓ', 'С', '‚', 'С', '‹', 'Р', 'є']
# ['С', 'Ѓ', 'С', 'ѓ', 'Р', 'є', 'Р', '°']
# ['С', 'Ѓ', 'С', 'ѓ', 'С', 'Ђ', 'Р', '°']
# ['С', 'Ѓ', 'С', 'ѓ', 'С', '€', 'Р', '°']
# ['С', 'Ѓ', 'С', '†', 'Р', 'µ', 'Р', 'ї']
# ['С', 'Ѓ', 'С', '‡', 'Р', '°', 'Р', '»']
# ['С', 'Ѓ', 'С', '‡', 'С', '‘', 'С', 'Ѓ']
# ['С', 'Ѓ', 'С', '‹', 'С', 'Ђ', 'С', '‚']
# ['С', 'Ѓ', 'С', '‹', 'С', 'Ѓ', 'Р', 'є']
# ['С', '‚', 'Р', '°', 'Р', 'І', 'С', 'Ђ']
# ['С', '‚', 'Р', '°', 'Р', '№', 'Р', 'ј']
# ['С', '‚', 'Р', '°', 'С', 'Ђ', 'Р', '°']
# ['С', '‚', 'Р', 'І', 'Р', 'ё', 'Р', 'ґ']
# ['С', '‚', 'Р', 'І', 'Р', 'ё', 'Р', 'Ѕ']
# ['С', '‚', 'Р', 'µ', 'Р', 'ё', 'Р', 'Ѕ']
# ['С', '‚', 'Р', 'µ', 'Р', '»', 'Р', 'ѕ']
# ['С', '‚', 'Р', 'µ', 'Р', 'ј', 'Р', 'ї']
# ['С', '‚', 'Р', 'µ', 'Р', 'ј', 'С', 'Џ']
# ['С', '‚', 'Р', 'µ', 'Р', 'Ѕ', 'С', '‚']
# ['С', '‚', 'С', '‘', 'С', 'Ђ', 'Р', 'Ѕ']
# ['С', '‚', 'Р', 'µ', 'С', 'Ђ', 'С', '†']
# ['С', '‚', 'Р', 'µ', 'С', 'Ѓ', 'С', '‚']
# ['С', '‚', 'Р', 'µ', 'С', '‚', 'Р', '°']
# ['С', '‚', 'С', '‘', 'С', '€', 'Р', '°']
# ['С', '‚', 'С', '‘', 'С', '‰', 'Р', '°']
# ['С', '‚', 'Р', 'ё', 'Р', 'Ѕ', 'Р', '°']
# ['С', '‚', 'Р', 'ё', 'С', 'Ђ', 'С', 'Ѓ']
# ['С', '‚', 'Р', 'ё', 'С', 'ѓ', 'Р', 'Ѕ']
# ['С', '‚', 'Р', 'є', 'Р', '°', 'С', '‡']
# ['С', '‚', 'Р', '»', 'Р', 'µ', 'Р', 'Ѕ']
# ['С', '‚', 'Р', 'ј', 'Р', 'ё', 'Р', 'Ѕ']
# ['С', '‚', 'Р', 'ѕ', 'Р', 'і', 'Р', '°']
# ['С', '‚', 'Р', 'ѕ', 'Р', '»', 'С', 'Њ']
# ['С', '‚', 'Р', 'ѕ', 'Р', 'Ѕ', 'С', 'Џ']
# ['С', '‚', 'Р', 'ѕ', 'Р', 'ї', 'С', 'Њ']
# ['С', '‚', 'Р', 'ѕ', 'С', 'Ђ', 'Р', 'є']
# ['С', '‚', 'Р', 'ѕ', 'С', 'Ђ', 'С', 'Ѓ']
# ['С', '‚', 'Р', 'ѕ', 'С', 'Ђ', 'С', '‚']
# ['С', '‚', 'Р', 'ѕ', 'С', 'Ђ', 'С', '„']
# ['С', '‚', 'С', 'Ђ', 'Р', '°', 'Р', 'є']
# ['С', '‚', 'С', 'Ђ', 'Р', '°', 'Р', '»']
# ['С', '‚', 'С', 'Ђ', 'Р', 'µ', 'Р', 'є']
# ['С', '‚', 'С', 'Ђ', 'Р', 'µ', 'Р', 'Ѕ']
# ['С', '‚', 'С', 'Ђ', 'Р', 'ё', 'Р', 'ї']
# ['С', '‚', 'С', 'Ђ', 'Р', 'ѕ', 'Р', 'і']
# ['С', '‚', 'С', 'Ђ', 'Р', 'ѕ', 'Р', 'є']
# ['С', '‚', 'С', 'Ђ', 'Р', 'ѕ', 'Р', 'Ѕ']
# ['С', '‚', 'С', 'Ђ', 'Р', 'ѕ', 'Р', 'ї']
# ['С', '‚', 'С', 'Ђ', 'Р', 'ѕ', 'С', 'Ѓ']
# ['С', '‚', 'С', 'Ђ', 'Р', 'ѕ', 'С', '‚']
# ['С', '‚', 'С', 'Ђ', 'С', 'ѓ', 'Р', 'ґ']
# ['С', '‚', 'С', 'Ђ', 'С', 'ѓ', 'Р', 'ї']
# ['С', '‚', 'С', 'Ђ', 'С', 'Ћ', 'Р', 'є']
# ['С', '‚', 'С', 'Ђ', 'С', 'Ћ', 'Р', 'ј']
# ['С', '‚', 'С', 'ѓ', 'Р', 'µ', 'С', 'Ђ']
# ['С', '‚', 'С', 'ѓ', 'Р', 'Ѕ', 'Р', '°']
# ['С', '‚', 'С', 'ѓ', 'Р', 'Ѕ', 'Р', 'і']
# ['С', '‚', 'С', 'ѓ', 'С', 'Ђ', 'Р', '°']
# ['С', '‚', 'С', 'ѓ', 'С', '‚', 'Р', '°']
# ['С', '‚', 'С', 'ѓ', 'С', '‡', 'Р', '°']
# ['С', '‚', 'С', 'ѓ', 'С', '€', 'С', 'Њ']
# ['С', '‚', 'С', 'Ћ', 'Р', '»', 'С', 'Њ']
# ['С', '‚', 'С', 'Ћ', 'С', 'Ђ', 'Р', 'є']
# ['С', 'ѓ', 'Р', '±', 'Р', 'ѕ', 'Р', '№']
# ['С', 'ѓ', 'Р', '±', 'Р', 'ѕ', 'С', 'Ђ']
# ['С', 'ѓ', 'Р', 'І', 'Р', 'ѕ', 'Р', 'ґ']
# ['С', 'ѓ', 'Р', 'І', 'Р', 'ѕ', 'Р', '·']
# ['С', 'ѓ', 'Р', 'ґ', 'Р', '°', 'Р', 'І']
# ['С', 'ѓ', 'Р', 'ґ', 'Р', '°', 'С', 'Ђ']
# ['С', 'ѓ', 'Р', 'ґ', 'Р', 'ѕ', 'Р', 'ґ']
# ['С', 'ѓ', 'Р', 'ґ', 'Р', 'ѕ', 'Р', '№']
# ['С', 'ѓ', 'Р', 'ґ', 'Р', 'ѕ', 'Р', '»']
# ['С', 'ѓ', 'Р', 'µ', 'Р', '·', 'Р', 'ґ']
# ['С', 'ѓ', 'Р', '·', 'Р', 'ґ', 'Р', '°']
# ['С', 'ѓ', 'Р', '·', 'Р', 'ё', 'Р', 'є']
# ['С', 'ѓ', 'Р', '·', 'Р', 'ѕ', 'С', 'Ђ']
# ['С', 'ѓ', 'Р', 'є', 'Р', '°', 'Р', '·']
# ['С', 'ѓ', 'Р', 'є', 'Р', 'ѕ', 'Р', '»']
# ['С', 'ѓ', 'Р', 'є', 'Р', 'ѕ', 'С', 'Ђ']
# ['С', 'ѓ', 'Р', 'є', 'Р', 'ѕ', 'С', 'Ѓ']
# ['С', 'ѓ', 'Р', 'є', 'С', 'ѓ', 'С', 'Ѓ']
# ['С', 'ѓ', 'Р', '»', 'Р', '°', 'Р', 'Ѕ']
# ['С', 'ѓ', 'Р', '»', 'Р', '°', 'С', 'Ђ']
# ['С', 'ѓ', 'Р', '»', 'Р', 'µ', 'Р', '№']
# ['С', 'ѓ', 'Р', '»', 'Р', 'µ', 'Р', 'ј']
# ['С', 'ѓ', 'Р', '»', 'Р', 'ё', 'С', '‚']
# ['С', 'ѓ', 'Р', '»', 'Р', 'ѕ', 'Р', 'І']
# ['С', 'ѓ', 'Р', '»', 'С', 'ѓ', 'С', 'Ѓ']
# ['С', 'ѓ', 'Р', '»', 'С', 'Њ', 'С', '‡']
# ['С', 'ѓ', 'Р', 'ї', 'С', '‘', 'Р', 'є']
# ['С', 'ѓ', 'Р', 'ї', 'Р', 'ѕ', 'С', 'Ђ']
# ['С', 'ѓ', 'С', 'Ђ', 'Р', '°', 'Р', 'Ѕ']
# ['С', 'ѓ', 'С', 'Ђ', 'Р', 'µ', 'Р', '·']
# ['С', 'ѓ', 'С', 'Ђ', 'Р', 'Ѕ', 'Р', '°']
# ['С', 'ѓ', 'С', 'Ђ', 'Р', 'ѕ', 'Р', 'ґ']
# ['С', 'ѓ', 'С', 'Ђ', 'Р', 'ѕ', 'Р', 'є']
# ['С', 'ѓ', 'С', 'Ђ', 'Р', 'ѕ', 'Р', 'Ѕ']
# ['С', 'ѓ', 'С', 'Ђ', 'С', 'Ћ', 'Р', 'є']
# ['С', 'ѓ', 'С', '‚', 'С', '‘', 'С', 'Ѓ']
# ['С', 'ѓ', 'С', '‚', 'Р', 'ѕ', 'Р', 'є']
# ['С', 'ѓ', 'С', '‚', 'Р', 'ѕ', 'С', 'Ђ']
# ['С', 'ѓ', 'С', '‚', 'С', 'Ђ', 'Р', 'ѕ']
# ['С', 'ѓ', 'С', '‚', 'С', 'Ћ', 'Р', 'і']
# ['С', 'ѓ', 'С', '…', 'Р', '°', 'Р', '±']
# ['С', 'ѓ', 'С', '‡', 'Р', '°', 'Р', 'Ѕ']
# ['С', 'ѓ', 'С', '‡', 'С', '‘', 'С', '‚']
# ['С', 'ѓ', 'С', '€', 'Р', '°', 'Р', 'Ѕ']
# ['С', 'ѓ', 'С', '€', 'Р', '°', 'С', '‚']
# ['С', 'ѓ', 'С', '€', 'Р', 'ё', 'Р', '±']
# ['С', '„', 'Р', '°', 'Р', '№', 'Р', '»']
# ['С', '„', 'Р', '°', 'Р', 'є', 'С', 'Ѓ']
# ['С', '„', 'Р', '°', 'Р', '»', 'Р', '»']
# ['С', '„', 'Р', '°', 'Р', 'Ѕ', 'Р', 'і']
# ['С', '„', 'Р', '°', 'Р', 'Ѕ', 'С', '‚']
# ['С', '„', 'Р', '°', 'С', 'Ђ', 'Р', '°']
# ['С', '„', 'Р', '°', 'С', 'Ђ', 'С', 'Ѓ']
# ['С', '„', 'Р', '°', 'С', 'Ђ', 'С', '€']
# ['С', '„', 'Р', '°', 'С', '‚', 'Р', '°']
# ['С', '„', 'Р', '°', 'С', 'ѓ', 'С', '‚']
# ['С', '„', 'Р', 'µ', 'Р', 'ѕ', 'Р', 'ґ']
# ['С', '„', 'Р', 'µ', 'С', '‚', 'С', 'Ђ']
# ['С', '„', 'Р', 'ё', 'Р', '°', 'Р', '»']
# ['С', '„', 'Р', 'ё', 'Р', '»', 'Р', '°']
# ['С', '„', 'Р', 'ё', 'Р', 'Ѕ', 'Р', 'Ѕ']
# ['С', '„', 'Р', 'ё', 'Р', 'Ѕ', 'С', '‚']
# ['С', '„', 'Р', 'ё', 'С', 'Ђ', 'Р', 'Ѕ']
# ['С', '„', 'Р', 'ё', 'С', '‚', 'Р', '°']
# ['С', '„', 'Р', '»', 'Р', '°', 'С', '‚']
# ['С', '„', 'Р', '»', 'С', '‘', 'С', 'Ђ']
# ['С', '„', 'Р', '»', 'Р', 'µ', 'С', '€']
# ['С', '„', 'Р', '»', 'Р', 'ё', 'Р', 'є']
# ['С', '„', 'Р', '»', 'Р', 'ѕ', 'С', '‚']
# ['С', '„', 'Р', 'ѕ', 'Р', 'і', 'С', '‚']
# ['С', '„', 'Р', 'ѕ', 'С', 'Ђ', 'Р', 'ґ']
# ['С', '„', 'Р', 'ѕ', 'С', 'Ђ', 'С', '‚']
# ['С', '„', 'С', 'Ђ', 'Р', '°', 'Р', 'є']
# ['С', '„', 'С', '‚', 'Р', 'ѕ', 'С', 'Ђ']
# ['С', '„', 'С', 'ѓ', 'Р', 'і', 'Р', '°']
# ['С', '„', 'С', 'ѓ', 'С', 'Ђ', 'Р', '°']
# ['С', '…', 'Р', '°', 'Р', 'ґ', 'Р', '¶']
# ['С', '…', 'Р', '°', 'Р', '»', 'Р', '°']
# ['С', '…', 'Р', '°', 'С', 'Ђ', 'С', 'Џ']
# ['С', '…', 'Р', '°', 'С', '‚', 'Р', '°']
# ['С', '…', 'Р', 'І', 'Р', 'ѕ', 'С', '‰']
# ['С', '…', 'Р', 'І', 'Р', 'ѕ', 'С', 'Џ']
# ['С', '…', 'Р', 'µ', 'С', '‚', 'С', '‚']
# ['С', '…', 'Р', 'ё', 'Р', 'Ѕ', 'Р', '°']
# ['С', '…', 'Р', '»', 'Р', '°', 'Р', 'ј']
# ['С', '…', 'Р', '»', 'Р', 'µ', 'Р', '±']
# ['С', '…', 'Р', '»', 'Р', 'µ', 'Р', 'І']
# ['С', '…', 'Р', '»', 'Р', 'ѕ', 'С', 'Ђ']
# ['С', '…', 'Р', 'ѕ', 'Р', '»', 'Р', '»']
# ['С', '…', 'Р', 'ѕ', 'Р', '»', 'Р', 'ј']
# ['С', '…', 'Р', 'ѕ', 'С', 'Ђ', 'С', '‚']
# ['С', '…', 'Р', 'ѕ', 'С', 'Ђ', 'С', 'Њ']
# ['С', '…', 'Р', 'ѕ', 'С', '‚', 'Р', '°']
# ['С', '…', 'С', 'Ђ', 'Р', '°', 'Р', 'ј']
# ['С', '…', 'С', 'Ђ', 'Р', 'ё', 'С', 'Џ']
# ['С', '…', 'С', 'Ђ', 'С', 'ѓ', 'С', '‰']
# ['С', '…', 'С', 'Ђ', 'С', 'Џ', 'Р', 'є']
# ['С', '…', 'С', 'ѓ', 'Р', '»', 'Р', '°']
# ['С', '†', 'Р', '°', 'С', 'Ђ', 'С', 'Њ']
# ['С', '†', 'Р', 'µ', 'Р', '»', 'С', 'Њ']
# ['С', '†', 'Р', 'µ', 'Р', 'Ѕ', 'Р', '°']
# ['С', '†', 'Р', 'µ', 'Р', 'Ѕ', 'Р', '·']
# ['С', '†', 'Р', 'µ', 'Р', 'Ѕ', 'С', '‚']
# ['С', '†', 'Р', 'µ', 'Р', 'ї', 'С', 'Њ']
# ['С', '†', 'Р', 'ё', 'Р', 'є', 'Р', '»']
# ['С', '†', 'Р', 'ё', 'Р', 'Ѕ', 'Р', 'є']
# ['С', '‡', 'Р', '°', 'Р', 'і', 'Р', '°']
# ['С', '‡', 'Р', '°', 'С', 'ѓ', 'С', 'Ѓ']
# ['С', '‡', 'Р', '°', 'С', 'ѓ', 'С', '€']
# ['С', '‡', 'Р', '°', 'С', '€', 'Р', '°']
# ['С', '‡', 'Р', '°', 'С', '‰', 'Р', '°']
# ['С', '‡', 'Р', 'µ', 'Р', 'є', 'Р', '°']
# ['С', '‡', 'С', '‘', 'Р', '»', 'Р', 'Ѕ']
# ['С', '‡', 'Р', 'µ', 'С', '‚', 'Р', '°']
# ['С', '‡', 'Р', 'ё', 'Р', 'Ѕ', 'Р', '°']
# ['С', '‡', 'С', '‚', 'Р', 'µ', 'С', '†']
# ['С', '‡', 'С', 'ѓ', 'Р', 'ґ', 'С', 'Њ']
# ['С', '‡', 'С', 'ѓ', 'Р', 'Ѕ', 'С', 'Џ']
# ['С', '€', 'Р', '°', 'Р', '»', 'Р', '°']
# ['С', '€', 'Р', '°', 'Р', 'Ѕ', 'С', 'Ѓ']
# ['С', '€', 'Р', '°', 'Р', 'Ѕ', 'С', '†']
# ['С', '€', 'Р', '°', 'С', 'Ђ', 'Р', '¶']
# ['С', '€', 'Р', '°', 'С', 'Ђ', 'Р', 'ј']
# ['С', '€', 'Р', 'І', 'Р', '°', 'Р', '±']
# ['С', '€', 'Р', 'І', 'Р', 'µ', 'Р', 'ґ']
# ['С', '€', 'Р', 'І', 'Р', 'µ', 'С', 'Џ']
# ['С', '€', 'Р', 'µ', 'Р', '№', 'Р', 'є']
# ['С', '€', 'Р', 'µ', 'Р', '№', 'С', '…']
# ['С', '€', 'С', '‘', 'Р', '»', 'Р', 'є']
# ['С', '€', 'Р', 'µ', 'С', 'Ђ', 'Р', '»']
# ['С', '€', 'Р', 'µ', 'С', 'Ђ', 'Р', 'ї']
# ['С', '€', 'Р', 'µ', 'С', 'Ѓ', 'С', '‚']
# ['С', '€', 'Р', 'ё', 'Р', 'ё', 'С', '‚']
# ['С', '€', 'Р', 'ё', 'Р', '»', 'Р', 'ѕ']
# ['С', '€', 'Р', 'ё', 'С', 'Ђ', 'С', 'Њ']
# ['С', '€', 'Р', 'є', 'Р', '°', 'С', '„']
# ['С', '€', 'Р', 'є', 'Р', 'ё', 'Р', 'І']
# ['С', '€', 'Р', 'є', 'Р', 'ѕ', 'С', '‚']
# ['С', '€', 'Р', '»', 'Р', '°', 'Р', 'і']
# ['С', '€', 'Р', '»', 'Р', '°', 'Р', 'є']
# ['С', '€', 'Р', '»', 'Р', '°', 'Р', 'ј']
# ['С', '€', 'Р', '»', 'Р', 'µ', 'С', 'Џ']
# ['С', '€', 'Р', '»', 'Р', 'ё', 'С', 'Ђ']
# ['С', '€', 'Р', '»', 'Р', 'ё', 'С', '„']
# ['С', '€', 'Р', '»', 'Р', 'ё', 'С', '…']
# ['С', '€', 'Р', '»', 'С', '‹', 'Р', 'є']
# ['С', '€', 'Р', '»', 'С', 'Ћ', 'Р', '·']
# ['С', '€', 'Р', '»', 'С', 'Ћ', 'Р', 'ї']
# ['С', '€', 'Р', 'Ѕ', 'Р', 'µ', 'Р', 'є']
# ['С', '€', 'Р', 'Ѕ', 'С', 'ѓ', 'С', 'Ђ']
# ['С', '€', 'Р', 'ї', 'Р', 'ё', 'С', '†']
# ['С', '€', 'Р', 'ї', 'Р', 'ѕ', 'С', 'Ђ']
# ['С', '€', 'Р', 'ї', 'С', 'ѓ', 'С', 'Ђ']
# ['С', '€', 'С', 'Ђ', 'Р', '°', 'Р', 'ј']
# ['С', '€', 'С', 'Ђ', 'Р', 'ѕ', 'С', '‚']
# ['С', '€', 'С', '‚', 'Р', '°', 'Р', '±']
# ['С', '€', 'С', '‚', 'Р', '°', 'Р', 'і']
# ['С', '€', 'С', '‚', 'Р', 'ѕ', 'С', 'Ѓ']
# ['С', '€', 'С', '‚', 'С', 'ѓ', 'С', '„']
# ['С', '€', 'С', '‚', 'С', '‹', 'Р', '±']
# ['С', '€', 'С', 'ѓ', 'Р', 'і', 'Р', '°']
# ['С', '€', 'С', 'ѓ', 'С', 'Ђ', 'С', '„']
# ['С', '€', 'С', 'ѓ', 'С', 'Ѓ', 'С', '‚']
# ['С', '‰', 'Р', 'µ', 'Р', 'ї', 'Р', '°']
# ['С', 'Ќ', 'Р', 'І', 'Р', 'µ', 'Р', 'Ѕ']
# ['С', 'Ќ', 'Р', 'ґ', 'Р', 'µ', 'Р', 'ј']
# ['С', 'Ќ', 'Р', 'ґ', 'Р', 'ё', 'Р', '»']
# ['С', 'Ќ', 'Р', 'є', 'Р', 'µ', 'С', 'Ђ']
# ['С', 'Ќ', 'Р', '»', 'С', 'Њ', 'С', '„']
# ['С', 'Ќ', 'Р', 'ј', 'Р', 'ё', 'С', 'Ђ']
# ['С', 'Ќ', 'Р', 'ї', 'Р', 'ѕ', 'С', 'Ѓ']
# ['С', 'Ќ', 'Р', 'ї', 'С', 'Ћ', 'С', 'Ђ']
# ['С', 'Ќ', 'С', 'Ѓ', 'Р', 'µ', 'С', 'Ђ']
# ['С', 'Ќ', 'С', '‚', 'Р', '°', 'Р', '¶']
# ['С', 'Ќ', 'С', '‚', 'Р', '°', 'Р', 'Ѕ']
# ['С', 'Ќ', 'С', '‚', 'Р', 'ё', 'Р', '»']
# ['С', 'Ќ', 'С', '‚', 'С', 'Ћ', 'Р', 'ґ']
# ['С', 'Ќ', 'С', '„', 'Р', 'µ', 'С', 'Ѓ']
# ['С', 'Ќ', 'С', '„', 'Р', 'ѕ', 'С', 'Ђ']
# ['С', 'Ќ', 'С', '…', 'Р', 'ё', 'Р', 'Ѕ']
# ['С', 'Ћ', 'Р', '°', 'Р', 'Ѕ', 'С', 'Њ']
# ['С', 'Ћ', 'Р', 'є', 'Р', 'є', 'Р', '°']
# ['С', 'Ћ', 'Р', '»', 'Р', 'є', 'Р', '°']
# ['С', 'Ћ', 'Р', 'ј', 'Р', 'ѕ', 'С', 'Ђ']
# ['С', 'Ћ', 'Р', 'Ѕ', 'Р', '°', 'Р', 'є']
# ['С', 'Ћ', 'Р', 'Ѕ', 'Р', 'і', 'Р', '°']
# ['С', 'Ћ', 'С', 'Ђ', 'Р', 'ѕ', 'Р', 'є']
# ['С', 'Ћ', 'С', 'Ђ', 'С', '‚', 'Р', '°']
# ['С', 'Ћ', 'С', '„', 'С', '‚', 'С', 'Њ']
# ['С', 'Ћ', 'С', 'Ћ', 'Р', '±', 'Р', '°']
# ['С', 'Џ', 'Р', 'І', 'Р', 'ѕ', 'С', 'Ђ']
# ['С', 'Џ', 'Р', '№', 'Р', '»', 'Р', '°']
# ['С', 'Џ', 'Р', '№', 'С', '†', 'Р', 'ѕ']
# ['С', 'Џ', 'Р', 'є', 'С', 'ѓ', 'С', '‚']
# ['С', 'Џ', 'Р', '»', 'Р', 'ё', 'Р', 'є']
# ['С', 'Џ', 'Р', 'Ѕ', 'С', 'ѓ', 'С', 'Ѓ']
# ['С', 'Џ', 'С', 'Ђ', 'Р', 'є', 'Р', '°']
# ['С', 'Џ', 'С', '…', 'С', '‚', 'Р', '°']
# ['С', 'Џ', 'С', '€', 'Р', 'ј', 'Р', '°']
# ['С', 'Џ', 'С', '‰', 'Р', 'µ', 'С', 'Ђ']
# ['С', 'Џ', 'С', '‰', 'Р', 'ё', 'Р', 'є']
# ['С', 'Џ', 'С', '‰', 'С', 'ѓ', 'С', 'Ђ']
# ['Р', '°', 'Р', '±', 'Р', '°', 'Р', 'є', 'Р', '°']
# ['Р', '°', 'Р', '±', 'Р', '±', 'Р', '°', 'С', '‚']
# ['Р', '°', 'Р', '±', 'Р', 'І', 'Р', 'µ', 'С', 'Ђ']
# ['Р', '°', 'Р', '±', 'Р', '·', 'Р', '°', 'С', '†']
# ['Р', '°', 'Р', '±', 'Р', 'ѕ', 'С', 'Ђ', 'С', '‚']
# ['Р', '°', 'Р', '±', 'С', 'Ђ', 'Р', 'µ', 'Р', 'є']
# ['Р', '°', 'Р', '±', 'С', 'Ђ', 'Р', 'ё', 'С', 'Ѓ']
# ['Р', '°', 'Р', '±', 'С', '…', 'Р', '°', 'Р', '·']
# ['Р', '°', 'Р', '±', 'С', '†', 'С', 'ѓ', 'Р', 'і']
# ['Р', '°', 'Р', 'І', 'Р', '°', 'Р', 'Ѕ', 'С', 'Ѓ']
# ['Р', '°', 'Р', 'І', 'Р', 'і', 'Р', 'ё', 'С', '‚']
# ['Р', '°', 'Р', 'І', 'Р', 'і', 'С', 'ѓ', 'С', 'Ђ']
# ['Р', '°', 'Р', 'І', 'С', 'Ђ', 'Р', '°', 'Р', '»']
# ['Р', '°', 'Р', 'І', 'С', '‚', 'Р', 'ѕ', 'Р', '»']
# ['Р', '°', 'Р', 'І', 'С', '‚', 'Р', 'ѕ', 'С', 'Ђ']
# ['Р', '°', 'Р', 'і', 'Р', '°', 'Р', 'І', 'Р', '°']
# ['Р', '°', 'Р', 'і', 'Р', '°', 'Р', 'ј', 'Р', '°']
# ['Р', '°', 'Р', 'і', 'Р', 'Ѕ', 'Р', '°', 'С', '‚']
# ['Р', '°', 'Р', 'ґ', 'Р', 'µ', 'Р', 'ї', 'С', '‚']
# ...
# ['С', 'Ѓ', 'Р', 'ѕ', 'Р', 'ј', 'Р', 'Ѕ', 'Р', 'ѕ', 'Р', '¶', 'Р', 'ё', 'С', '‚', 'Р', 'µ', 'Р', '»', 'С', 'Њ']
# ['С', 'Ѓ', 'Р', 'ѕ', 'Р', 'Ѕ', 'Р', '°', 'С', 'Ѓ', 'Р', '»', 'Р', 'µ', 'Р', 'ґ', 'Р', 'Ѕ', 'Р', 'ё', 'Р', 'є']
# ['С', 'Ѓ', 'Р', 'ѕ', 'Р', 'ѕ', 'Р', '±', 'С', 'Ђ', 'Р', '°', 'Р', '¶', 'Р', 'µ', 'Р', 'Ѕ', 'Р', 'ё', 'Р', 'µ']
# ['С', 'Ѓ', 'Р', 'ѕ', 'Р', 'ѕ', 'С', '‚', 'Р', 'І', 'Р', 'µ', 'С', '‚', 'С', '‡', 'Р', 'ё', 'С', '†', 'Р', '°']
# ['С', 'Ѓ', 'Р', 'ѕ', 'Р', 'ѕ', 'С', '‚', 'Р', 'Ѕ', 'Р', 'µ', 'С', 'Ѓ', 'Р', 'µ', 'Р', 'Ѕ', 'Р', 'ё', 'Р', 'µ']
# ['С', 'Ѓ', 'Р', 'ѕ', 'Р', 'ѕ', 'С', '‚', 'Р', 'Ѕ', 'Р', 'ѕ', 'С', '€', 'Р', 'µ', 'Р', 'Ѕ', 'Р', 'ё', 'Р', 'µ']
# ['С', 'Ѓ', 'Р', 'ѕ', 'Р', 'ї', 'Р', '»', 'Р', 'µ', 'Р', 'ј', 'Р', 'µ', 'Р', 'Ѕ', 'Р', 'Ѕ', 'Р', 'ё', 'Р', 'є']
# ['С', 'Ѓ', 'Р', 'ѕ', 'Р', 'ї', 'С', 'Ђ', 'Р', '°', 'Р', 'І', 'Р', 'ё', 'С', '‚', 'Р', 'µ', 'Р', '»', 'С', 'Њ']
# ['С', 'Ѓ', 'Р', 'ѕ', 'С', 'Ђ', 'Р', 'ѕ', 'Р', 'є', 'Р', '°', 'Р', '»', 'Р', 'µ', 'С', '‚', 'Р', 'ё', 'Р', 'µ']
# ['С', 'Ѓ', 'Р', 'ѕ', 'С', 'Ѓ', 'Р', 'є', 'С', 'Ђ', 'Р', 'µ', 'Р', '±', 'Р', '°', 'Р', 'Ѕ', 'Р', 'ё', 'Р', 'µ']
# ['С', 'Ѓ', 'Р', 'ѕ', 'С', 'Ѓ', 'Р', '»', 'Р', 'ѕ', 'Р', 'І', 'Р', 'Ѕ', 'Р', 'ѕ', 'С', 'Ѓ', 'С', '‚', 'С', 'Њ']
# ['С', 'Ѓ', 'Р', 'ѕ', 'С', 'Ѓ', 'Р', '»', 'С', 'ѓ', 'Р', '¶', 'Р', 'ё', 'Р', 'І', 'Р', 'ё', 'С', '†', 'Р', '°']
# ['С', 'Ѓ', 'Р', 'ѕ', 'С', 'Ѓ', 'С', '‚', 'Р', '°', 'Р', 'І', 'Р', 'ё', 'С', '‚', 'Р', 'µ', 'Р', '»', 'С', 'Њ']
# ['С', 'Ѓ', 'Р', 'ѕ', 'С', 'Ѓ', 'С', '‚', 'Р', '°', 'Р', 'І', 'Р', '»', 'Р', 'µ', 'Р', 'Ѕ', 'Р', 'ё', 'Р', 'µ']
# ['С', 'Ѓ', 'Р', 'ѕ', 'С', 'Ѓ', 'С', '‚', 'С', 'Ђ', 'Р', '°', 'Р', 'ґ', 'Р', '°', 'Р', 'Ѕ', 'Р', 'ё', 'Р', 'µ']
# ['С', 'Ѓ', 'Р', 'ѕ', 'С', 'Ѓ', 'С', '‚', 'С', 'Ђ', 'Р', 'ё', 'Р', 'і', 'Р', '°', 'Р', 'Ѕ', 'Р', 'ё', 'Р', 'µ']
# ['С', 'Ѓ', 'Р', 'ѕ', 'С', 'ѓ', 'С', '‡', 'Р', '°', 'С', 'Ѓ', 'С', '‚', 'Р', 'Ѕ', 'Р', 'ё', 'С', '†', 'Р', '°']
# ['С', 'Ѓ', 'Р', 'ѕ', 'С', '…', 'С', 'Ђ', 'Р', '°', 'Р', 'Ѕ', 'Р', 'Ѕ', 'Р', 'ѕ', 'С', 'Ѓ', 'С', '‚', 'С', 'Њ']
# ['С', 'Ѓ', 'Р', 'ѕ', 'С', '†', 'Р', 'ё', 'Р', '°', 'Р', '»', 'Р', 'ё', 'С', 'Ѓ', 'С', '‚', 'Р', 'є', 'Р', '°']
# ['С', 'Ѓ', 'Р', 'ї', 'Р', '°', 'С', 'Ђ', 'С', '‚', 'Р', '°', 'Р', 'є', 'Р', 'ё', 'Р', '°', 'Р', 'ґ', 'Р', '°']
# ['С', 'Ѓ', 'Р', 'ї', 'Р', 'µ', 'Р', 'є', 'Р', '°', 'Р', 'µ', 'Р', 'ј', 'Р', 'ѕ', 'С', 'Ѓ', 'С', '‚', 'С', 'Њ']
# ['С', 'Ѓ', 'Р', 'ї', 'Р', 'µ', 'Р', 'є', 'С', '‚', 'С', 'Ђ', 'Р', 'ѕ', 'Р', 'і', 'С', 'Ђ', 'Р', '°', 'С', '„']
# ['С', 'Ѓ', 'Р', 'ї', 'Р', 'µ', 'Р', 'є', 'С', '‚', 'С', 'Ђ', 'Р', 'ѕ', 'Р', 'ј', 'Р', 'µ', 'С', '‚', 'С', 'Ђ']
# ['С', 'Ѓ', 'Р', 'ї', 'Р', 'µ', 'Р', 'є', 'С', '‚', 'С', 'Ђ', 'Р', 'ѕ', 'С', 'Ѓ', 'Р', 'є', 'Р', 'ѕ', 'Р', 'ї']
# ['С', 'Ѓ', 'Р', 'ї', 'Р', 'µ', 'Р', 'є', 'С', 'ѓ', 'Р', '»', 'С', 'Џ', 'Р', 'Ѕ', 'С', '‚', 'Р', 'є', 'Р', '°']
# ['С', 'Ѓ', 'Р', 'ї', 'Р', 'µ', 'Р', '»', 'Р', 'µ', 'Р', 'ѕ', 'Р', '»', 'Р', 'ѕ', 'Р', 'і', 'Р', 'ё', 'С', 'Џ']
# ['С', 'Ѓ', 'Р', 'ї', 'Р', 'ё', 'Р', 'Ѕ', 'Р', 'Ѕ', 'Р', 'ё', 'Р', 'Ѕ', 'Р', 'і', 'Р', 'ё', 'С', 'Ѓ', 'С', '‚']
# ['С', 'Ѓ', 'Р', 'ї', 'Р', 'ё', 'С', 'Ђ', 'Р', 'ѕ', 'Р', 'ј', 'Р', 'µ', 'С', '‚', 'С', 'Ђ', 'Р', 'ё', 'С', 'Џ']
# ['С', 'Ѓ', 'Р', 'ї', 'Р', 'ё', 'С', 'Ђ', 'С', '‚', 'Р', 'ѕ', 'Р', 'І', 'Р', '°', 'Р', 'Ѕ', 'Р', 'ё', 'Р', 'µ']
# ['С', 'Ѓ', 'Р', 'ї', 'Р', '»', 'Р', '°', 'С', '‡', 'Р', 'ё', 'Р', 'І', 'Р', '°', 'Р', 'Ѕ', 'Р', 'ё', 'Р', 'µ']
# ['С', 'Ѓ', 'Р', 'ї', 'Р', '»', 'С', '‘', 'Р', 'І', 'С', '‹', 'Р', 'І', 'Р', '°', 'Р', 'Ѕ', 'Р', 'ё', 'Р', 'µ']
# ['С', 'Ѓ', 'Р', 'ї', 'Р', '»', 'С', 'Ћ', 'С', '‰', 'Р', 'ё', 'Р', 'І', 'Р', '°', 'Р', 'Ѕ', 'Р', 'ё', 'Р', 'µ']
# ['С', 'Ѓ', 'Р', 'ї', 'Р', 'ѕ', 'Р', 'ґ', 'Р', 'І', 'Р', 'ё', 'Р', '¶', 'Р', 'Ѕ', 'Р', 'ё', 'С', '†', 'Р', '°']
# ['С', 'Ѓ', 'Р', 'ї', 'Р', 'ѕ', 'Р', 'є', 'Р', 'ѕ', 'Р', '№', 'С', 'Ѓ', 'С', '‚', 'Р', 'І', 'Р', 'ё', 'Р', 'µ']
# ['С', 'Ѓ', 'Р', 'ї', 'Р', 'ѕ', 'С', 'Ђ', 'Р', 'ѕ', 'Р', '»', 'Р', 'ё', 'С', 'Ѓ', 'С', '‚', 'Р', 'ё', 'Р', 'є']
# ['С', 'Ѓ', 'Р', 'ї', 'Р', 'ѕ', 'С', 'Ђ', 'С', '‚', 'С', 'Ѓ', 'Р', 'ј', 'Р', 'µ', 'Р', 'Ѕ', 'Р', 'є', 'Р', '°']
# ['С', 'Ѓ', 'Р', 'ї', 'С', 'Ђ', 'Р', '°', 'С', '€', 'Р', 'ё', 'Р', 'І', 'Р', '°', 'Р', 'Ѕ', 'Р', 'ё', 'Р', 'µ']
# ['С', 'Ѓ', 'Р', 'ї', 'С', 'Ђ', 'С', '‹', 'Р', 'і', 'Р', 'ё', 'Р', 'І', 'Р', '°', 'Р', 'Ѕ', 'Р', 'ё', 'Р', 'µ']
# ['С', 'Ѓ', 'Р', 'ї', 'С', 'ѓ', 'С', '‚', 'Р', '°', 'Р', 'Ѕ', 'Р', 'Ѕ', 'Р', 'ѕ', 'С', 'Ѓ', 'С', '‚', 'С', 'Њ']
# ['С', 'Ѓ', 'С', 'Ђ', 'Р', '°', 'Р', 'І', 'Р', 'Ѕ', 'Р', 'ё', 'Р', 'ј', 'Р', 'ѕ', 'С', 'Ѓ', 'С', '‚', 'С', 'Њ']
# ['С', 'Ѓ', 'С', 'Ђ', 'Р', 'µ', 'Р', '·', 'Р', '°', 'Р', '»', 'С', 'Њ', 'С', '‰', 'Р', 'ё', 'С', '†', 'Р', '°']
# ['С', 'Ѓ', 'С', 'Ѓ', 'С', 'ѓ', 'Р', 'ґ', 'Р', 'ѕ', 'Р', 'ґ', 'Р', '°', 'С', '‚', 'Р', 'µ', 'Р', '»', 'С', 'Њ']
# ['С', 'Ѓ', 'С', 'Ѓ', 'С', '‹', 'Р', 'ї', 'Р', '°', 'Р', '»', 'С', 'Њ', 'С', '‰', 'Р', 'ё', 'С', '†', 'Р', '°']
# ['С', 'Ѓ', 'С', '‚', 'Р', '°', 'Р', 'І', 'Р', '»', 'Р', 'µ', 'Р', 'Ѕ', 'Р', 'Ѕ', 'Р', 'ё', 'С', '†', 'Р', '°']
# ['С', 'Ѓ', 'С', '‚', 'Р', '°', 'Р', 'І', 'С', 'Ђ', 'Р', 'ѕ', 'Р', 'ї', 'Р', 'ё', 'Р', 'і', 'Р', 'ё', 'С', 'Џ']
# ['С', 'Ѓ', 'С', '‚', 'Р', '°', 'Р', 'ґ', 'Р', 'ё', 'Р', '№', 'Р', 'Ѕ', 'Р', 'ѕ', 'С', 'Ѓ', 'С', '‚', 'С', 'Њ']
# ['С', 'Ѓ', 'С', '‚', 'Р', '°', 'Р', '»', 'Р', 'є', 'Р', 'ё', 'Р', 'І', 'Р', '°', 'Р', 'Ѕ', 'Р', 'ё', 'Р', 'µ']
# ['С', 'Ѓ', 'С', '‚', 'Р', '°', 'Р', 'Ѕ', 'Р', 'ѕ', 'Р', 'І', 'Р', '»', 'Р', 'µ', 'Р', 'Ѕ', 'Р', 'ё', 'Р', 'µ']
# ['С', 'Ѓ', 'С', '‚', 'Р', '°', 'Р', 'ї', 'Р', '»', 'Р', 'ё', 'Р', 'І', 'Р', '°', 'Р', 'Ѕ', 'Р', 'ё', 'Р', 'µ']
# ['С', 'Ѓ', 'С', '‚', 'Р', '°', 'Р', 'ї', 'С', '‚', 'С', '‹', 'Р', 'І', 'Р', '°', 'Р', 'Ѕ', 'Р', 'ё', 'Р', 'µ']
# ['С', 'Ѓ', 'С', '‚', 'Р', '°', 'С', 'Ђ', 'С', 'Њ', 'С', '‘', 'Р', 'І', 'С', '‰', 'Р', 'ё', 'С', '†', 'Р', '°']
# ['С', 'Ѓ', 'С', '‚', 'Р', '°', 'С', '‚', 'Р', 'ё', 'С', '‡', 'Р', 'Ѕ', 'Р', 'ѕ', 'С', 'Ѓ', 'С', '‚', 'С', 'Њ']
# ['С', 'Ѓ', 'С', '‚', 'Р', 'µ', 'Р', '±', 'Р', '»', 'Р', 'µ', 'Р', 'І', 'Р', '°', 'Р', 'Ѕ', 'Р', 'ё', 'Р', 'µ']
# ['С', 'Ѓ', 'С', '‚', 'Р', 'µ', 'Р', 'і', 'Р', '°', 'Р', '»', 'С', 'Њ', 'С', '‰', 'Р', 'ё', 'С', '†', 'Р', '°']
# ['С', 'Ѓ', 'С', '‚', 'Р', 'µ', 'Р', 'є', 'Р', '»', 'Р', 'ё', 'Р', '»', 'С', 'Њ', 'С', '‰', 'Р', 'ё', 'Р', 'є']
# ['С', 'Ѓ', 'С', '‚', 'Р', 'µ', 'Р', 'є', 'Р', '»', 'Р', 'ѕ', 'Р', 'І', 'Р', '°', 'Р', 'Ѕ', 'Р', 'ё', 'Р', 'µ']
# ['С', 'Ѓ', 'С', '‚', 'Р', 'µ', 'Р', 'є', 'Р', '»', 'Р', 'ѕ', 'Р', 'ґ', 'Р', 'µ', 'Р', '»', 'Р', 'ё', 'Р', 'µ']
# ['С', 'Ѓ', 'С', '‚', 'Р', 'µ', 'Р', 'є', 'Р', '»', 'Р', 'ѕ', 'Р', 'ј', 'Р', '°', 'С', 'Ѓ', 'С', 'Ѓ', 'Р', '°']
# ['С', 'Ѓ', 'С', '‚', 'Р', 'µ', 'Р', 'є', 'Р', '»', 'С', 'Џ', 'Р', 'Ѕ', 'Р', 'Ѕ', 'Р', 'ё', 'С', '†', 'Р', '°']
# ['С', 'Ѓ', 'С', '‚', 'Р', 'µ', 'Р', 'Ѕ', 'Р', 'ѕ', 'Р', 'і', 'С', 'Ђ', 'Р', '°', 'Р', 'ј', 'Р', 'ј', 'Р', '°']
# ['С', 'Ѓ', 'С', '‚', 'Р', 'µ', 'Р', 'Ѕ', 'Р', 'ѕ', 'Р', 'і', 'С', 'Ђ', 'Р', '°', 'С', '„', 'Р', 'ё', 'С', 'Џ']
# ['С', 'Ѓ', 'С', '‚', 'Р', 'µ', 'Р', 'Ѕ', 'Р', 'ѕ', 'Р', 'є', 'Р', '°', 'С', 'Ђ', 'Р', 'ґ', 'Р', 'ё', 'С', 'Џ']
# ['С', 'Ѓ', 'С', '‚', 'Р', 'µ', 'Р', 'Ѕ', 'Р', 'ѕ', 'С', '‚', 'Р', 'ё', 'Р', 'ї', 'Р', 'ё', 'С', 'Ѓ', 'С', '‚']
# ['С', 'Ѓ', 'С', '‚', 'Р', 'µ', 'Р', 'ї', 'Р', 'µ', 'Р', 'Ѕ', 'Р', 'Ѕ', 'Р', 'ѕ', 'С', 'Ѓ', 'С', '‚', 'С', 'Њ']
# ['С', 'Ѓ', 'С', '‚', 'Р', 'µ', 'С', 'Ђ', 'Р', 'µ', 'Р', 'ѕ', 'С', '‚', 'Р', 'ё', 'Р', 'ї', 'С', '‘', 'С', 'Ђ']
# ['С', 'Ѓ', 'С', '‚', 'Р', 'µ', 'С', 'Ђ', 'Р', 'µ', 'Р', 'ѕ', 'С', '„', 'Р', 'ѕ', 'Р', 'Ѕ', 'Р', 'ё', 'С', 'Џ']
# ['С', 'Ѓ', 'С', '‚', 'Р', 'µ', 'С', 'Ђ', 'Р', '¶', 'Р', 'µ', 'Р', 'Ѕ', 'С', '‰', 'Р', 'ё', 'С', '†', 'Р', '°']
# ['С', 'Ѓ', 'С', '‚', 'Р', 'µ', 'С', '‚', 'Р', 'ѕ', 'С', 'Ѓ', 'Р', 'є', 'Р', 'ѕ', 'Р', 'ї', 'Р', 'ё', 'С', 'Џ']
# ['С', 'Ѓ', 'С', '‚', 'Р', 'ё', 'С', '…', 'Р', 'ё', 'Р', '№', 'Р', 'Ѕ', 'Р', 'ѕ', 'С', 'Ѓ', 'С', '‚', 'С', 'Њ']
# ['С', 'Ѓ', 'С', '‚', 'Р', 'ѕ', 'Р', 'ј', 'Р', '°', 'С', '‚', 'Р', 'ѕ', 'С', 'Ѓ', 'Р', 'є', 'Р', 'ѕ', 'Р', 'ї']
# ['С', 'Ѓ', 'С', '‚', 'Р', 'ѕ', 'Р', 'ї', '-', 'С', 'Ѓ', 'Р', 'ё', 'Р', 'і', 'Р', 'Ѕ', 'Р', '°', 'Р', '»']
# ['С', 'Ѓ', 'С', '‚', 'С', 'Ђ', 'Р', '°', 'С', 'Ѓ', 'С', '‚', 'Р', 'Ѕ', 'Р', 'ѕ', 'С', 'Ѓ', 'С', '‚', 'С', 'Њ']
# ['С', 'Ѓ', 'С', '‚', 'С', 'Ђ', 'Р', '°', 'С', 'Ѓ', 'С', '‚', 'Р', 'ѕ', 'С', '†', 'Р', 'І', 'Р', 'µ', 'С', '‚']
# ['С', 'Ѓ', 'С', '‚', 'С', 'Ђ', 'Р', '°', 'С', '‚', 'Р', 'ё', 'С', 'Ѓ', 'С', '„', 'Р', 'µ', 'С', 'Ђ', 'Р', '°']
# ['С', 'Ѓ', 'С', '‚', 'С', 'Ђ', 'Р', '°', 'С', '‚', 'Р', 'ѕ', 'С', 'Ѓ', 'С', '„', 'Р', 'µ', 'С', 'Ђ', 'Р', '°']
# ['С', 'Ѓ', 'С', '‚', 'С', 'Ђ', 'Р', '°', 'С', 'ѓ', 'С', 'Ѓ', 'С', 'Џ', 'С', '‚', 'Р', 'ё', 'Р', 'Ѕ', 'Р', '°']
# ['С', 'Ѓ', 'С', '‚', 'С', 'Ђ', 'Р', '°', 'С', 'ѓ', 'С', 'Ѓ', 'С', 'Џ', 'С', '‚', 'Р', 'Ѕ', 'Р', 'ё', 'Р', 'є']
# ['С', 'Ѓ', 'С', '‚', 'С', 'Ђ', 'Р', 'µ', 'Р', 'є', 'Р', 'ѕ', 'С', '‚', 'Р', '°', 'Р', 'Ѕ', 'Р', 'ё', 'Р', 'µ']
# ['С', 'Ѓ', 'С', '‚', 'С', 'Ђ', 'Р', 'µ', 'Р', '»', 'Р', 'ѕ', 'С', '‡', 'Р', 'Ѕ', 'Р', 'ё', 'С', '†', 'Р', '°']
# ['С', 'Ѓ', 'С', '‚', 'С', 'Ђ', 'Р', 'µ', 'Р', 'ї', 'С', '‚', 'Р', 'ѕ', 'Р', 'є', 'Р', 'ѕ', 'Р', 'є', 'Р', 'є']
# ['С', 'Ѓ', 'С', '‚', 'С', 'Ђ', 'Р', 'ё', 'Р', 'і', 'Р', '°', 'Р', '»', 'С', 'Њ', 'С', '‰', 'Р', 'ё', 'Р', 'є']
# ['С', 'Ѓ', 'С', '‚', 'С', 'Ђ', 'Р', 'ё', 'Р', 'і', 'Р', 'ѕ', 'Р', '»', 'С', 'Њ', 'Р', 'Ѕ', 'Р', 'ё', 'Р', 'є']
# ['С', 'Ѓ', 'С', '‚', 'С', 'Ђ', 'Р', 'ѕ', 'Р', 'і', 'Р', '°', 'Р', '»', 'С', 'Њ', 'С', '‰', 'Р', 'ё', 'Р', 'є']
# ['С', 'Ѓ', 'С', '‚', 'С', 'Ђ', 'Р', 'ѕ', 'Р', 'ї', 'Р', '°', 'Р', '»', 'С', 'Њ', 'С', '‰', 'Р', 'ё', 'Р', 'є']
# ['С', 'Ѓ', 'С', '‚', 'С', 'Ђ', 'С', 'ѓ', 'Р', 'і', 'Р', '°', 'Р', '»', 'С', 'Њ', 'С', '‰', 'Р', 'ё', 'Р', 'є']
# ['С', 'Ѓ', 'С', '‚', 'С', 'Ђ', 'С', 'ѓ', 'Р', 'Ѕ', 'Р', 'ѕ', 'Р', '±', 'Р', 'µ', 'С', '‚', 'Р', 'ѕ', 'Р', 'Ѕ']
# ['С', 'Ѓ', 'С', '‚', 'С', 'Ђ', 'С', 'Џ', 'Р', 'ї', 'С', '‡', 'Р', 'µ', 'С', 'Ѓ', 'С', '‚', 'Р', 'І', 'Р', 'ѕ']
# ['С', 'Ѓ', 'С', '‚', 'С', 'Ђ', 'С', 'Џ', 'С', '…', 'Р', 'ё', 'Р', 'І', 'Р', '°', 'Р', 'Ѕ', 'Р', 'ё', 'Р', 'µ']
# ['С', 'Ѓ', 'С', '‚', 'С', '‹', 'Р', 'ґ', 'Р', '»', 'Р', 'ё', 'Р', 'І', 'Р', 'ѕ', 'С', 'Ѓ', 'С', '‚', 'С', 'Њ']
# ['С', 'Ѓ', 'С', 'ѓ', 'Р', '±', 'Р', '»', 'Р', 'ё', 'С', '‚', 'Р', 'ѕ', 'С', 'Ђ', 'Р', '°', 'Р', '»', 'С', 'Њ']
# ['С', 'Ѓ', 'С', 'ѓ', 'Р', '±', 'С', 'Ѓ', 'С', '‚', 'Р', 'ё', 'С', '‚', 'С', 'ѓ', 'С', '†', 'Р', 'ё', 'С', 'Џ']
# ['С', 'Ѓ', 'С', 'ѓ', 'Р', 'І', 'Р', 'µ', 'С', 'Ђ', 'Р', 'µ', 'Р', 'Ѕ', 'Р', 'ё', 'С', '‚', 'Р', 'µ', 'С', '‚']
# ['С', 'Ѓ', 'С', 'ѓ', 'Р', 'ґ', 'Р', 'ѕ', 'С', 'Ђ', 'Р', '°', 'Р', '±', 'Р', 'ѕ', 'С', '‡', 'Р', 'ё', 'Р', '№']
# ['С', 'Ѓ', 'С', 'ѓ', 'Р', 'ґ', 'Р', 'ѕ', 'С', '…', 'Р', 'ѕ', 'Р', 'ґ', 'С', 'Ѓ', 'С', '‚', 'Р', 'І', 'Р', 'ѕ']
# ['С', 'Ѓ', 'С', 'ѓ', 'Р', 'µ', 'Р', 'І', 'Р', 'µ', 'С', 'Ђ', 'Р', 'Ѕ', 'Р', 'ѕ', 'С', 'Ѓ', 'С', '‚', 'С', 'Њ']
# ['С', 'Ѓ', 'С', 'ѓ', 'Р', 'µ', 'С', '‚', 'Р', '»', 'Р', 'ё', 'Р', 'І', 'Р', 'ѕ', 'С', 'Ѓ', 'С', '‚', 'С', 'Њ']
# ['С', 'Ѓ', 'С', 'ѓ', 'Р', 'є', 'Р', 'ѕ', 'Р', 'І', 'Р', '°', 'С', '‚', 'Р', 'ѕ', 'С', 'Ѓ', 'С', '‚', 'С', 'Њ']
# ['С', 'Ѓ', 'С', 'ѓ', 'Р', '»', 'С', 'Њ', 'С', '„', 'Р', 'ё', 'С', '‚', 'Р', '°', 'С', '†', 'Р', 'ё', 'С', 'Џ']
# ['С', 'Ѓ', 'С', 'ѓ', 'Р', 'ј', 'Р', '±', 'С', 'ѓ', 'С', 'Ђ', 'Р', 'Ѕ', 'Р', 'ѕ', 'С', 'Ѓ', 'С', '‚', 'С', 'Њ']
# ['С', 'Ѓ', 'С', 'ѓ', 'Р', 'ј', 'С', 'Ђ', 'Р', '°', 'С', '‡', 'Р', 'Ѕ', 'Р', 'ѕ', 'С', 'Ѓ', 'С', '‚', 'С', 'Њ']
# ['С', 'Ѓ', 'С', 'ѓ', 'Р', 'ї', 'Р', 'µ', 'С', 'Ђ', 'Р', '°', 'С', 'Ђ', 'Р', '±', 'Р', 'ё', 'С', '‚', 'С', 'Ђ']
# ['С', 'Ѓ', 'С', 'ѓ', 'Р', 'ї', 'Р', 'µ', 'С', 'Ђ', 'Р', 'ј', 'Р', '°', 'С', 'Ђ', 'Р', 'є', 'Р', 'µ', 'С', '‚']
# ['С', 'Ѓ', 'С', 'ѓ', 'Р', 'ї', 'Р', 'µ', 'С', 'Ђ', 'Р', 'ј', 'Р', 'ѕ', 'Р', 'ґ', 'Р', 'µ', 'Р', '»', 'С', 'Њ']
# ['С', 'Ѓ', 'С', 'ѓ', 'Р', 'ї', 'Р', 'µ', 'С', 'Ђ', 'С', '„', 'Р', 'ѕ', 'С', 'Ѓ', 'С', '„', 'Р', '°', 'С', '‚']
# ['С', 'Ѓ', 'С', 'ѓ', 'Р', 'ї', 'Р', 'ѕ', 'С', 'Ђ', 'Р', 'ѕ', 'С', 'Ѓ', 'Р', 'ѕ', 'С', 'Ѓ', 'С', '‚', 'С', 'Њ']
# ['С', 'Ѓ', 'С', 'ѓ', 'Р', 'ї', 'С', 'Ђ', 'Р', 'µ', 'Р', 'ј', 'Р', '°', 'С', '‚', 'Р', 'ё', 'Р', '·', 'Р', 'ј']
# ['С', 'Ѓ', 'С', 'ѓ', 'Р', 'ї', 'С', 'Ђ', 'Р', 'µ', 'Р', 'ј', 'Р', '°', 'С', '‚', 'Р', 'ё', 'С', 'Ѓ', 'С', '‚']
# ['С', 'Ѓ', 'С', 'ѓ', 'Р', 'ї', 'С', 'Ђ', 'С', 'ѓ', 'Р', '¶', 'Р', 'µ', 'С', 'Ѓ', 'С', '‚', 'Р', 'І', 'Р', 'ѕ']
# ['С', 'Ѓ', 'С', 'ѓ', 'С', 'Ѓ', 'Р', '°', 'Р', '»', 'С', 'Њ', 'Р', 'Ѕ', 'Р', 'ѕ', 'С', 'Ѓ', 'С', '‚', 'С', 'Њ']
# ['С', 'Ѓ', 'С', 'ѓ', 'С', 'Ѓ', 'Р', 'ї', 'Р', 'µ', 'Р', 'Ѕ', 'Р', '·', 'Р', 'ѕ', 'С', 'Ђ', 'Р', 'ё', 'Р', '№']
# ['С', 'Ѓ', 'С', 'ѓ', 'С', '„', 'С', 'Ђ', 'Р', '°', 'Р', '¶', 'Р', 'ё', 'С', 'Ѓ', 'С', '‚', 'Р', 'є', 'Р', '°']
# ['С', 'Ѓ', 'С', 'ѓ', 'С', '„', 'С', '„', 'Р', 'ё', 'Р', 'є', 'С', 'Ѓ', 'Р', '°', 'С', '†', 'Р', 'ё', 'С', 'Џ']
# ['С', 'Ѓ', 'С', 'ѓ', 'С', '…', 'Р', 'ѕ', 'Р', 'І', 'Р', '°', 'С', '‚', 'Р', 'ѕ', 'С', 'Ѓ', 'С', '‚', 'С', 'Њ']
# ['С', 'Ѓ', 'С', 'ѓ', 'С', '…', 'Р', 'ѕ', 'С', 'Ѓ', 'С', '‚', 'Р', 'ѕ', 'Р', '№', 'Р', 'Ѕ', 'Р', 'ё', 'Р', 'є']
# ['С', 'Ѓ', 'С', 'ѓ', 'С', '…', 'Р', 'ѕ', 'С', '‰', 'Р', '°', 'Р', 'І', 'Р', 'ѕ', 'С', 'Ѓ', 'С', '‚', 'С', 'Њ']
# ['С', 'Ѓ', 'С', '„', 'С', 'Ђ', 'Р', '°', 'Р', 'і', 'Р', 'ё', 'С', 'Ѓ', 'С', '‚', 'Р', 'ё', 'Р', 'є', 'Р', '°']
# ['С', 'Ѓ', 'С', '…', 'Р', 'І', 'Р', '°', 'С', '‚', 'С', '‹', 'Р', 'І', 'Р', '°', 'Р', 'Ѕ', 'Р', 'ё', 'Р', 'µ']
# ['С', 'Ѓ', 'С', '…', 'Р', 'ё', 'Р', '·', 'Р', 'ј', 'Р', '°', 'С', '‚', 'Р', 'ё', 'С', '‡', 'Р', 'є', 'Р', '°']
# ['С', 'Ѓ', 'С', '…', 'Р', 'ё', 'Р', 'ј', 'Р', 'ѕ', 'Р', 'Ѕ', 'Р', '°', 'С', '…', 'Р', 'ё', 'Р', 'Ѕ', 'С', 'Џ']
# ['С', 'Ѓ', 'С', '†', 'Р', 'µ', 'Р', 'Ѕ', 'Р', '°', 'С', 'Ђ', 'Р', 'ё', 'С', 'Ѓ', 'С', '‚', 'Р', 'є', 'Р', '°']
# ['С', 'Ѓ', 'С', '†', 'Р', 'µ', 'Р', 'Ѕ', 'Р', 'ё', 'С', '‡', 'Р', 'Ѕ', 'Р', 'ѕ', 'С', 'Ѓ', 'С', '‚', 'С', 'Њ']
# ['С', 'Ѓ', 'С', '‡', 'Р', 'µ', 'С', 'Ђ', 'Р', 'ї', 'С', '‹', 'Р', 'І', 'Р', '°', 'Р', 'Ѕ', 'Р', 'ё', 'Р', 'µ']
# ['С', 'Ѓ', 'С', '‡', 'Р', 'µ', 'С', 'Ђ', 'С', '‡', 'Р', 'ё', 'Р', 'І', 'Р', '°', 'Р', 'Ѕ', 'Р', 'ё', 'Р', 'µ']
# ['С', 'Ѓ', 'С', '€', 'Р', 'ё', 'Р', 'І', 'Р', '°', 'Р', '»', 'С', 'Њ', 'С', '‰', 'Р', 'ё', 'С', '†', 'Р', '°']
# ['С', 'Ѓ', 'С', 'Љ', 'Р', 'µ', 'Р', 'ґ', 'Р', 'ѕ', 'Р', '±', 'Р', 'Ѕ', 'Р', 'ѕ', 'С', 'Ѓ', 'С', '‚', 'С', 'Њ']
# ['С', 'Ѓ', 'С', '‹', 'Р', 'і', 'С', 'Ђ', 'Р', '°', 'Р', 'Ѕ', 'Р', 'Ѕ', 'Р', 'ѕ', 'С', 'Ѓ', 'С', '‚', 'С', 'Њ']
# ['С', 'Ѓ', 'С', '‹', 'С', 'Ђ', 'Р', 'ѕ', 'Р', 'І', 'Р', '°', 'С', 'Ђ', 'Р', 'µ', 'Р', 'Ѕ', 'Р', 'ё', 'Р', 'µ']
# ['С', 'Ѓ', 'С', 'Ћ', 'Р', '·', 'Р', 'µ', 'С', 'Ђ', 'Р', 'µ', 'Р', 'Ѕ', 'Р', 'ё', 'С', '‚', 'Р', 'µ', 'С', '‚']
# ['С', '‚', 'Р', '°', 'Р', '±', 'Р', '°', 'С', 'Ѓ', 'Р', '°', 'С', 'Ђ', 'Р', '°', 'Р', 'Ѕ', 'Р', 'µ', 'С', '†']
# ['С', '‚', 'Р', '°', 'Р', '±', 'Р', '°', 'С', 'Ѓ', 'Р', '°', 'С', 'Ђ', 'Р', '°', 'Р', 'Ѕ', 'Р', 'є', 'Р', '°']
# ['С', '‚', 'Р', '°', 'Р', '№', 'Р', 'Ѕ', 'Р', 'ѕ', 'Р', '±', 'С', 'Ђ', 'Р', '°', 'С', '‡', 'Р', 'ё', 'Р', 'µ']
# ['С', '‚', 'Р', '°', 'Р', 'є', 'С', '‚', 'Р', 'ё', 'С', '‡', 'Р', 'Ѕ', 'Р', 'ѕ', 'С', 'Ѓ', 'С', '‚', 'С', 'Њ']
# ['С', '‚', 'Р', '°', 'Р', 'ј', 'Р', '±', 'С', 'ѓ', 'С', 'Ђ', 'Р', 'ј', 'Р', '°', 'Р', '¶', 'Р', 'ѕ', 'С', 'Ђ']
# ['С', '‚', 'Р', '°', 'С', 'Ђ', 'Р', 'ё', 'С', 'Ђ', 'Р', 'ѕ', 'Р', 'І', 'Р', '°', 'Р', 'Ѕ', 'Р', 'ё', 'Р', 'µ']
# ['С', '‚', 'Р', '°', 'С', 'Ђ', 'Р', 'ё', 'С', '„', 'Р', 'ё', 'Р', 'є', 'Р', '°', 'С', '‚', 'Р', 'ѕ', 'С', 'Ђ']
# ['С', '‚', 'Р', '°', 'С', 'Ђ', 'Р', 'ё', 'С', '„', 'Р', 'ё', 'Р', 'є', 'Р', '°', 'С', '†', 'Р', 'ё', 'С', 'Џ']
# ['С', '‚', 'Р', '°', 'С', '‚', 'С', 'ѓ', 'Р', 'ё', 'С', 'Ђ', 'Р', 'ѕ', 'Р', 'І', 'С', '‰', 'Р', 'ё', 'Р', 'є']
# ['С', '‚', 'Р', '°', 'С', '…', 'Р', 'µ', 'Р', 'ѕ', 'Р', 'ј', 'Р', 'µ', 'С', '‚', 'С', 'Ђ', 'Р', 'ё', 'С', 'Џ']
# ['С', '‚', 'Р', 'µ', 'Р', '°', 'С', '‚', 'С', 'Ђ', 'Р', 'ѕ', 'Р', 'ј', 'Р', '°', 'Р', 'Ѕ', 'Р', 'ё', 'С', 'Џ']
# ['С', '‚', 'Р', 'µ', 'Р', '·', 'Р', 'ё', 'С', 'Ђ', 'Р', 'ѕ', 'Р', 'І', 'Р', '°', 'Р', 'Ѕ', 'Р', 'ё', 'Р', 'µ']
# ['С', '‚', 'Р', 'µ', 'Р', 'є', 'С', 'Ѓ', 'С', '‚', 'Р', 'ё', 'Р', '»', 'С', 'Њ', 'С', '‰', 'Р', 'ё', 'Р', 'є']
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
